# %% [markdown]
# # CNN attack using Skywater non-linearized data
#
# The goal of this notebook is to correctly preprocess the given data as tensors, train and test a CNN model.

# %%
# dataloader.py
# Necessary imports
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import os
import re

# %% [markdown]
# ## Creating dataloaders
# Used files from Kareem's GitHub repo. I may have made mistakes in sampling the data, so feel free to change anything that has been configured incorrectly.

# %% [markdown]
# ### Helper functions - Dataloaders

# %%
# dataloader.py
# Returns list of files with given format 
def get_files(directory, format, digital_index=0):

    format = re.compile(format)
    files = os.listdir(directory)

    #file_dict = {}
    file_list = [] # fname, fpath, label

    for fname in files:
        if match := format.match(fname):
            fpath = os.path.join(directory, fname)

            dvalue = int(match.groups()[digital_index])
            
            file_list.append((fname, fpath, dvalue))

            #if dvalue in file_dict:
            #    file_dict[dvalue].append(fpath)
            #else:
            #    file_dict[dvalue] = [fpath]

    return file_list #file_dict, file_path

# Creates dataset with given traces
class TraceDataset(Dataset):
    cached_traces = {}
    trace_list    = []

    def __init__(self, file_list, cache=True):
        self.file_list = file_list
        self.cache     = cache

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, index):
        fname, fpath, label = self.file_list[index]
        label = self.process_label(label)

        if self.cache and fname in self.cached_traces:
            return self.cached_traces[fname], label
        else:
            return self.load_trace(fname, fpath), label

    def get_info(self, index):
        return self.file_list[index]

    def load_trace(self, fname, fpath):
        with open(fpath, 'r') as file:
            header = file.readline()
            #time_arr = []
            valu_arr = []
            # Fixed error of float32 incorrectly translating values
            for line in file.readlines():
                time, value = line.strip().split()
                match = re.search(r"(?<=e-)\d+", value)
                if match:
                    strip_val = value[0:8]
                    # instead of manual string manipulation via index, used split for safety
                    if(match.group() != "04"):
                        integer_part, fractional_part = strip_val.split('.')
                        new_integer_part = integer_part + fractional_part[:4 - int(match.group())]
                        new_fractional_part = fractional_part[4 - int(match.group()):] 
                        strip_val = new_integer_part + '.' + new_fractional_part
                #time_arr.append(np.float32(time))
                valu_arr.append(np.float32(strip_val))

        trace = np.array(valu_arr, dtype=np.float32)

        if self.cache: 
            self.cached_traces[fname] = trace
            self.trace_list.append(trace)

        return trace
    
    def process_label(self, label): return label

    def cache_all(self):
        assert self.cache == True

        print("Caching all traces")
        for fname, fpath, label in self.file_list:
            self.load_trace(fname, fpath)
        print("DONE Caching all traces")

class TraceDatasetBW(TraceDataset):
    def __init__(self, file_list, bit_select, cache=True):
        self.bit_mask = 1 << bit_select
        super().__init__(file_list, cache=cache)

    def process_label(self, label):
        return 1 if label & self.bit_mask else 0

class TraceDatasetBuilder:
    def __init__(self, adc_bitwidth=8, cache=True):
        self.file_list        = []
        self.cache = cache
        self.adc_bits = adc_bitwidth

        self.dataset = None
        self.dataloader = None
        self.datasets = []
        self.dataloaders = []

    def add_files(self, directory, format, label_group):
        ''' Builds list of powertrace files
        Inputs:
            directory   : folder to search for files
            format      : regular expression to match filenames
            label_index : group index for digital output label corresponding to trace
        Outputs:
            list        : [(file_name, file_path, label) ... ]
        '''
        format = re.compile(format)
        fnames = os.listdir(directory)

        for fname in fnames:
            if match := format.match(fname):
                fpath = os.path.join(directory, fname)
                dvalue = int(match.groups()[label_group])

                self.file_list.append((fname, fpath, dvalue))

    def build(self):
        self.dataset = TraceDataset(self.file_list, cache=self.cache)
        for b in range(self.adc_bits):
            self.datasets.append(TraceDatasetBW(self.file_list, b, cache=self.cache))

        if self.cache:
            self.dataset.cache_all()

    def build_dataloaders(self, **kwargs): # batch_size=256, shuffle=True
        self.dataloader = DataLoader(self.dataset, **kwargs)
        self.dataloaders = [DataLoader(dataset, **kwargs) for dataset in self.datasets]

# %% [markdown]
# ## Creating dataloaders
# This section:
# 1) Creates dataloaders for both the training and testing datasets.
# 2) Validates and checks the contents of each dataset.
# 3) Common variables, such as "input_size" are instantiated.

# %%
# Hyperparameters for dataloaders
adc_bits = 8

# %%
# Create dataloaders
pwd = os.getcwd()
# print(pwd)
# proj_dir = os.path.dirname(os.path.dirname(pwd))
# print(proj_dir)
# data_dir = os.path.join(pwd, 'analog', 'outfiles')

builder  = TraceDatasetBuilder(adc_bitwidth=adc_bits, cache=True)
builder.add_files(os.path.join(pwd, 'sky_Dec_18_2151'), "sky_d(\\d+)_.*\\.txt", 0)
builder.build()
builder.build_dataloaders(batch_size=256, shuffle=True)

# Initialize dataloaders
dataloaders = builder.dataloaders

try:
    print(f"\nTotal number of datasets in dataloaders: {len(dataloaders)}")
except ModuleNotFoundError:
    print("\tERROR: Dataloader not found. Recheck your implementation and try again.")
    raise
except Exception as e:
    print("\tERROR: Dataloader invalid. Recheck your implementation and try again.")
    raise

if not dataloaders or len(dataloaders) != adc_bits:
    print(f"\tERROR: Dataloader size is incorrect: {len(dataloaders) if dataloaders else 0}. It should be: {adc_bits}.")
    print("\tRecheck your implementation and try again.")
    raise ValueError("Invalid dataloader size")

# Extract input_size and validate initial dataloader
input_size, label_num = None, None
for input, labels in dataloaders[0]:
    input_size = input.size(1)
    label_num = len(labels)
    print(f"Input size: {input_size}")
    print(f"Number of labels: {label_num}\n")

    if input.size(0) != label_num:
        print("\tERROR: Number of traces per input is different from number of labels.")
        print(f"\tNumber of traces per input: {input.size(0)}")
        print(f"\tNumber of labels: {label_num}\n")
        raise ValueError("Mismatch between input size and number of labels")

# Validate all dataloaders
for idx, dataloader in enumerate(dataloaders):
    for input, labels in dataloader:
        if input.size(0) != label_num:
            print(f"\tERROR: Number of traces per input is incorrect in dataloader {idx}.")
            print(f"\tExpected: {label_num}, but got: {input.size(0)}.")
            raise ValueError("Invalid number of traces per input")

        if input.size(1) != input_size:
            print(f"\tERROR: Size of traces per input is incorrect in dataloader {idx}.")
            print(f"\tExpected: {input_size}, but got: {input.size(1)}.")
            raise ValueError("Invalid trace size")

        if len(labels) != label_num:
            print(f"\tERROR: Number of labels is incorrect in dataloader {idx}.")
            print(f"\tExpected: {label_num}, but got: {len(labels)}.")
            raise ValueError("Invalid label count")

    print(f"Validation for dataloader {idx} complete.")

print("\nAll dataloaders are valid. Proceeding to training...")
# Out:
# Caching all traces
# DONE Caching all traces
#
# Total number of datasets in dataloaders: 8
# Input size: 3001
# Number of labels: 256
#
# Validation for dataloader 0 complete.
# Validation for dataloader 1 complete.
# Validation for dataloader 2 complete.
# Validation for dataloader 3 complete.
# Validation for dataloader 4 complete.
# Validation for dataloader 5 complete.
# Validation for dataloader 6 complete.
# Validation for dataloader 7 complete.
#
# All dataloaders are valid. Proceeding to training...

# %% [markdown]
# ### Setup for CNN
# Section where the initial imports and variables for our native CNN.

# %%
# CNN code
# Necessary imports
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
import numpy as np
import datetime

# %% [markdown]
# ### Optimizing CUDA version
# Section where we desginate the most updated CUDA version for current GPU.
#
# Implementation in progress, but is a lot of unnecessary work; will do if CPU training speeds are unformidable.

# %% [markdown]
# ## Training CNNs - Native CNN
# Using a native CNN, we train each CNN until all of them reaches an accuracy of 1.0.
#
# I'm not sure if aiming for an accuracy of 1.0 is beneficial, as it is just overfitting the model to the training data. A more realistic value may be 0.99, but will set it to 1.0 for the current simulated environment.
#
# The training function automatically reduces the learning rate used in Adam based on target accuracy. Currently testing different values and decrease rates.

# %% [markdown]
# ### Hyperparameters
#
# 1) def_lr: Default learning rate. Change this value to test different learning rate values.
# 2) max_epoch: Limit of maximum training epochs; training ends if it reaches this amount of epochs.

# %%
# Main hyperparameters
def_lr = 1e-4
max_epoch = 100000

# %% [markdown]
# ### CNN model initialization
# Function that initializes the CNN architecture.
#
# The architecture of the original CNN from the S2ADC paper is as follows:
#
# C = Convolution layer, [filter_num, kernel_size, stride]
#
# MP = Max Pool layer, [pool_zie, stride]
#
# FC = Fully Connected layer, [neuron_num]
#
# OUT = Output layer(another FC), [neuron_num]
#
# C1[5,5,1]
#
# MP1[5,5]
#
# C2[5,5,1]
#
# MP2[5,5]
#
# Flattening layer
#
# FC1[100]
#
# FC2[100]
#
# FC3[100]
#
# OUT[2]
#
# This architecture would most likely be needed to be tweaked for our usecase as our ADC is significiantly more complex.

# %%
# Class that defines our CNN model
class psa_CNN(nn.Module):
    def __init__(self):
        super(psa_CNN, self).__init__()
        # 1-D convolution layers
        # Activation = ReLU
        # 8 filters, kernel size = 5, stride = 1, zero padding
        # input = [label_num, input_size, 1]
        # output = [label_num, output_size, (input_size + 2p - d(k-1)-1)/s + 1]
        # = [label_num, output_size, (input_size + k)/s + 1]
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=8, kernel_size=5, stride=1, padding=2)
        self.conv2 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=5, stride=1, padding=2)
        self.conv3 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=5, stride=1, padding=2)
        self.conv4 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=5, stride=1, padding=2)
        self.conv5 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=5, stride=1, padding=2)
        self.conv6 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=5, stride=1, padding=2)
        # Pooling layers
        # MaxPool, pooling size = 3, stride = 3
        # input = [label_num, input_size, 1]
        # output = [label_num, (input_size + 2p - d(k-1) - 1)/s + 1, 1]
        # = [label_num, (input_size - 3)//3 + 1, 1]
        self.pool1 = nn.MaxPool1d(kernel_size=3, stride=3)
        self.pool2 = nn.MaxPool1d(kernel_size=3, stride=3)
        self.pool3 = nn.MaxPool1d(kernel_size=3, stride=3)
        self.pool4 = nn.MaxPool1d(kernel_size=3, stride=3)
        self.pool5 = nn.MaxPool1d(kernel_size=3, stride=3)
        self.pool6 = nn.MaxPool1d(kernel_size=3, stride=3)
        # Fully connected layers
        # Activation = ReLU
        # 100 neurons
        self.fc1 = nn.Linear(96, 500)
        self.fc2 = nn.Linear(500, 500)
        self.fc3 = nn.Linear(500, 500)
        # Output layer
        # 2 neurons, softmax
        self.o1 = nn.Linear(500, 2)

    def forward(self, x):
        x = x.unsqueeze(1)
        # First convolutional layer
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        x = torch.relu(self.conv3(x))
        x = self.pool3(x)
        x = torch.relu(self.conv4(x))
        x = self.pool4(x)
        x = torch.relu(self.conv5(x))
        x = self.pool5(x)
        '''
        x = torch.relu(self.conv6(x))
        x = self.pool6(x)
        '''
        # Flatten the output
        x = x.view(x.size(0), -1)
        # Fully connected layers
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        # Output layer, softmax
        x = torch.softmax(self.o1(x), dim=1)
        return x

# %% [markdown]
# ### Helper Functions

# %%
''' 
Function that initializes the CNN and its core components.
Inputs:
    None
Returns:
    1) cnn: model used(ResNet18)
    2) criterion: loss function, current default=CrossEntropyLoss
    3) learning_rate: learning rate, current default=def_lr
    4) optimizer: optimizer, current default=Adam
'''
def cnn_init():
    # Model: custom CNN, inspired by the S2ADC paper
    cnn = psa_CNN()
    # Loss function: not specified in paper, using Cross Entropy Loss
    criterion = nn.CrossEntropyLoss()

    # Learning rate: default set to def_lr, adjust accordingly
    # Optimizer: not specified in paper, using Adam
    learning_rate = def_lr
    optimizer = optim.Adam(cnn.parameters(), lr=learning_rate)
    return cnn, criterion, learning_rate, optimizer

''' 
Function that initializes parameters used in training.
Inputs:
    None
Returns:
    TRAINING PARAMETERS
    1) num_epochs: number of maximum epochs per training
    2) max_grad_norm: gradient clipping threshold
'''
def param_init():
    # training parameters
    num_epochs = max_epoch
    max_grad_norm = 1.0

    return num_epochs, max_grad_norm

''' 
Function that loads variables from saved .pth file. Checks if the file is valid.
This function simply receives the checkpoint file and checks if it is valid.
Inputs:
    1) checkpoint_path: string of .pth file name 
    2) device: selected device to run training
Returns:
    1) pth_variables: dictionary that contains received .pth variables.
    List of variables are saved in 'load_values' array.
'''
def load_pth_file(checkpoint_path, device, load_values):
    pth_variables = {}
    # Load .pth file
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=True)
        for values in load_values:
            pth_variables[values] = checkpoint.get(values, 0)
        return pth_variables
    except FileNotFoundError:
        print(f"No checkpoint found at {checkpoint_path}. Starting from scratch.")
        raise
    except KeyError as e:
        missing_keys = {
            'cnn_state_dict': "CNN state dictionary",
            'optimizer_state_dict': "optimizer state dictionary",
            'epoch': "epoch",
            'reached_acc': "recorded accuracy of current epoch",
            'osc_count': "oscillation count"
        }
        key = e.args[0]
        if key in missing_keys:
            if key in ['cnn_state_dict', 'optimizer_state_dict', 'epoch', 'reached_acc']:
                print(f"Critical error: Missing \"{key}\" that stores \"{missing_keys[key]}\". Checkpoint file is invalid.")
                raise
            else:
                print(f"Warning: Missing \"{key}\" that stores \"{missing_keys[key]}\". Default values will be used.")
                if key == 'osc_count':
                    osc_count = 0

        print(f"Unknown parameter \"{key}\" in checkpoint. Recheck file and try again.")
        raise

# %%
cnns = []
dataloaders = builder.dataloaders 
timestamp   = datetime.datetime.now().strftime('%Y%m%d_%H%M')

print(f"Installed CUDA version: {torch.version.cuda}\n")

# Create CNN per dataset
for i in range(7,-1,-1):
    print(f"Starting training for \"cnn_{i}\"...")

    # initialize CNN
    cnn, criterion, learning_rate, optimizer = cnn_init()
    # Save default learning rate
    default_lr = learning_rate
    # initialize parameters
    num_epochs, max_grad_norm = param_init()

    # Append CNN to cnns array
    cnns.append(cnn)

    # Create checkpoint to save progress
    checkpoint_path = f"cnn_checkpoint_{i}.pth"
    
    # Set device to cuda if available
    if torch.cuda.is_available():
        print("\tGPU found, running training on GPU...")
        device = torch.device("cuda")
        cnn = cnn.to(device)
    else:
        print("\tNo GPU found, running training on CPU...")
        print("\tRecheck CUDA version and if your GPU supports it.")
        device = torch.device("cpu")

    max_acc = 0
    max_acc_epoch = 0

    # Attempt to load saved .pth file
    # start_epoch = LOCAL variable that specifies starting epoch number
    # prev_acc = LOCAL variable that specifies accuracy achieved by loaded .pth file
    load_values = ['cnn_state_dict', 'optimizer_state_dict', 'epoch', 'reached_acc']
    try:
        pth_vars = load_pth_file(checkpoint_path, device, load_values)
    except FileNotFoundError:
        start_epoch = 0
        prev_acc = 0
        osc_count = 0
    else:
        # Manually create variables per value
        cnn.load_state_dict(pth_vars['cnn_state_dict'])
        optimizer.load_state_dict(pth_vars['optimizer_state_dict'])
        start_epoch = pth_vars['epoch']
        prev_acc = pth_vars['reached_acc']
        max_acc = prev_acc
        max_acc_epoch = start_epoch
    
        print(f"Checkpoint loaded. Resuming from epoch {start_epoch}.")
        print(f"\tPrevious reached accuracy: {prev_acc}.")

    # Skip training if target accuracy is reached
    if prev_acc == 1:
        print(f"\tSkipping training: accuracy of 1 already achieved.\n")
        continue

    # Start training
    for e in range(start_epoch, num_epochs):
        try:
            correct = 0
            cnn.train()

            for inputs, labels in dataloaders[i]:
                inputs, labels = inputs.to(device), labels.to(device)
                # Add dimensions for channels and width
                # inputs = inputs.unsqueeze(1).unsqueeze(-1)
                optimizer.zero_grad()
                output = cnn(inputs)
                # Check for NaN in outputs
                if torch.isnan(output).any():
                    print("NaN detected in cnn outputs.")
                    break

                loss = criterion(output, labels)
                # Check for NaN in loss
                if torch.isnan(loss):
                    print("NaN detected in loss. Stopping training.")
                    break
                # print(f"Loss: {loss.item()}")
                loss.backward()

                # Gradient clipping
                torch.nn.utils.clip_grad_norm_(cnn.parameters(), max_grad_norm)
                optimizer.step()
                _, predicted = torch.max(output, 1)
                correct += (predicted == labels).sum()
            
            accuracy = correct / 256
            if accuracy > max_acc:
                max_acc = accuracy
                max_acc_epoch = e + 1

            # Change rate of update for printing accuracy accordingly
            if (e + 1) % 50 == 0:
                print(f'\tTRAINING: cnn[{i}], Epoch {e+1}, Loss: {loss.item()}')
                print(f'\tTRAINING: cnn[{i}], Epoch {e+1}, Accuracy: {accuracy}')
                print(f'\tMax accuracy: {max_acc}')
                print(f'\tMax accuracy epoch: {max_acc_epoch}')

                # Save checkpoint
                torch.save({
                    'cnn_state_dict': cnn.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'epoch': e + 1,
                    'reached_acc': accuracy
                }, checkpoint_path)
                print(f"Checkpoint saved for epoch {e + 1}")

            prev_acc = accuracy

            if accuracy == 1:
                print(f"Reached accuracy of 1. Stopping training for \"cnn_{i}\".")
                print(f"Achieved epoch: {max_acc_epoch}\n")
                # Save checkpoint
                torch.save({
                    'cnn_state_dict': cnn.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'epoch': e + 1,
                    'reached_acc': accuracy
                }, checkpoint_path)
                break
        except KeyboardInterrupt:
            # Save checkpoint
            torch.save({
                'cnn_state_dict': cnn.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'epoch': e + 1,
                'reached_acc': accuracy
            }, checkpoint_path)
            print(f"Training interrupted. Pausing training...")
            print(f"Checkpoint saved for last epoch {e + 1}")
            print(f'\tFinal accuracy: {accuracy}')
            raise
# Out:
# Installed CUDA version: None
#
# Starting training for "cnn_7"...
# 	No GPU found, running training on CPU...
# 	Recheck CUDA version and if your GPU supports it.
# No checkpoint found at cnn_checkpoint_7.pth. Starting from scratch.
# 	TRAINING: cnn[7], Epoch 50, Loss: 0.6494647264480591
# 	TRAINING: cnn[7], Epoch 50, Accuracy: 0.98828125
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 50
# Checkpoint saved for epoch 50
# Reached accuracy of 1. Stopping training for "cnn_7".
# Achieved epoch: 53
#
# Starting training for "cnn_6"...
# 	No GPU found, running training on CPU...
# 	Recheck CUDA version and if your GPU supports it.
# No checkpoint found at cnn_checkpoint_6.pth. Starting from scratch.
# 	TRAINING: cnn[6], Epoch 50, Loss: 0.6622064709663391
# 	TRAINING: cnn[6], Epoch 50, Accuracy: 0.51953125
# 	Max accuracy: 0.70703125
# 	Max accuracy epoch: 8
# Checkpoint saved for epoch 50
# 	TRAINING: cnn[6], Epoch 100, Loss: 0.6227927803993225
# 	TRAINING: cnn[6], Epoch 100, Accuracy: 0.53125
# 	Max accuracy: 0.70703125
# 	Max accuracy epoch: 8
# Checkpoint saved for epoch 100
# 	TRAINING: cnn[6], Epoch 150, Loss: 0.4606034457683563
# 	TRAINING: cnn[6], Epoch 150, Accuracy: 0.921875
# 	Max accuracy: 0.94140625
# 	Max accuracy epoch: 147
# Checkpoint saved for epoch 150
# 	TRAINING: cnn[6], Epoch 200, Loss: 0.3716578483581543
# 	TRAINING: cnn[6], Epoch 200, Accuracy: 0.9765625
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 198
# Checkpoint saved for epoch 200
# 	TRAINING: cnn[6], Epoch 250, Loss: 0.3426934778690338
# 	TRAINING: cnn[6], Epoch 250, Accuracy: 0.99609375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 231
# Checkpoint saved for epoch 250
# 	TRAINING: cnn[6], Epoch 300, Loss: 0.338338702917099
# 	TRAINING: cnn[6], Epoch 300, Accuracy: 0.9921875
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 231
# Checkpoint saved for epoch 300
# Reached accuracy of 1. Stopping training for "cnn_6".
# Achieved epoch: 310
#
# Starting training for "cnn_5"...
# 	No GPU found, running training on CPU...
# 	Recheck CUDA version and if your GPU supports it.
# No checkpoint found at cnn_checkpoint_5.pth. Starting from scratch.
# 	TRAINING: cnn[5], Epoch 50, Loss: 0.6767177581787109
# 	TRAINING: cnn[5], Epoch 50, Accuracy: 0.625
# 	Max accuracy: 0.625
# 	Max accuracy epoch: 50
# Checkpoint saved for epoch 50
# 	TRAINING: cnn[5], Epoch 100, Loss: 0.6658563017845154
# 	TRAINING: cnn[5], Epoch 100, Accuracy: 0.52734375
# 	Max accuracy: 0.625
# 	Max accuracy epoch: 50
# Checkpoint saved for epoch 100
# 	TRAINING: cnn[5], Epoch 150, Loss: 0.6421751379966736
# 	TRAINING: cnn[5], Epoch 150, Accuracy: 0.72265625
# 	Max accuracy: 0.72265625
# 	Max accuracy epoch: 149
# Checkpoint saved for epoch 150
# 	TRAINING: cnn[5], Epoch 200, Loss: 0.5801186561584473
# 	TRAINING: cnn[5], Epoch 200, Accuracy: 0.72265625
# 	Max accuracy: 0.7265625
# 	Max accuracy epoch: 199
# Checkpoint saved for epoch 200
# 	TRAINING: cnn[5], Epoch 250, Loss: 0.5405617952346802
# 	TRAINING: cnn[5], Epoch 250, Accuracy: 0.8046875
# 	Max accuracy: 0.8046875
# 	Max accuracy epoch: 245
# Checkpoint saved for epoch 250
# 	TRAINING: cnn[5], Epoch 300, Loss: 0.5137416124343872
# 	TRAINING: cnn[5], Epoch 300, Accuracy: 0.8515625
# 	Max accuracy: 0.8828125
# 	Max accuracy epoch: 295
# Checkpoint saved for epoch 300
# 	TRAINING: cnn[5], Epoch 350, Loss: 0.4858410954475403
# 	TRAINING: cnn[5], Epoch 350, Accuracy: 0.8984375
# 	Max accuracy: 0.9296875
# 	Max accuracy epoch: 349
# Checkpoint saved for epoch 350
# 	TRAINING: cnn[5], Epoch 400, Loss: 0.4609343409538269
# 	TRAINING: cnn[5], Epoch 400, Accuracy: 0.9375
# 	Max accuracy: 0.9453125
# 	Max accuracy epoch: 389
# Checkpoint saved for epoch 400
# 	TRAINING: cnn[5], Epoch 450, Loss: 0.44501572847366333
# 	TRAINING: cnn[5], Epoch 450, Accuracy: 0.9453125
# 	Max accuracy: 0.95703125
# 	Max accuracy epoch: 412
# Checkpoint saved for epoch 450
# 	TRAINING: cnn[5], Epoch 500, Loss: 0.4230567514896393
# 	TRAINING: cnn[5], Epoch 500, Accuracy: 0.97265625
# 	Max accuracy: 0.97265625
# 	Max accuracy epoch: 478
# Checkpoint saved for epoch 500
# 	TRAINING: cnn[5], Epoch 550, Loss: 0.40522098541259766
# 	TRAINING: cnn[5], Epoch 550, Accuracy: 0.9609375
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 550
# 	TRAINING: cnn[5], Epoch 600, Loss: 0.39193904399871826
# 	TRAINING: cnn[5], Epoch 600, Accuracy: 0.97265625
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 600
# 	TRAINING: cnn[5], Epoch 650, Loss: 0.3891679644584656
# 	TRAINING: cnn[5], Epoch 650, Accuracy: 0.9609375
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 650
# 	TRAINING: cnn[5], Epoch 700, Loss: 0.3806142210960388
# 	TRAINING: cnn[5], Epoch 700, Accuracy: 0.97265625
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 700
# 	TRAINING: cnn[5], Epoch 750, Loss: 0.37371745705604553
# 	TRAINING: cnn[5], Epoch 750, Accuracy: 0.98046875
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 750
# 	TRAINING: cnn[5], Epoch 800, Loss: 0.37743547558784485
# 	TRAINING: cnn[5], Epoch 800, Accuracy: 0.9609375
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 800
# 	TRAINING: cnn[5], Epoch 850, Loss: 0.36503085494041443
# 	TRAINING: cnn[5], Epoch 850, Accuracy: 0.98046875
# 	Max accuracy: 0.984375
# 	Max accuracy epoch: 539
# Checkpoint saved for epoch 850
# 	TRAINING: cnn[5], Epoch 900, Loss: 0.3610559403896332
# 	TRAINING: cnn[5], Epoch 900, Accuracy: 0.98828125
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 900
# 	TRAINING: cnn[5], Epoch 950, Loss: 0.3664737641811371
# 	TRAINING: cnn[5], Epoch 950, Accuracy: 0.9609375
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 950
# 	TRAINING: cnn[5], Epoch 1000, Loss: 0.35647788643836975
# 	TRAINING: cnn[5], Epoch 1000, Accuracy: 0.9765625
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1000
# 	TRAINING: cnn[5], Epoch 1050, Loss: 0.35363420844078064
# 	TRAINING: cnn[5], Epoch 1050, Accuracy: 0.98828125
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1050
# 	TRAINING: cnn[5], Epoch 1100, Loss: 0.3593595325946808
# 	TRAINING: cnn[5], Epoch 1100, Accuracy: 0.96875
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1100
# 	TRAINING: cnn[5], Epoch 1150, Loss: 0.3505566716194153
# 	TRAINING: cnn[5], Epoch 1150, Accuracy: 0.98046875
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1150
# 	TRAINING: cnn[5], Epoch 1200, Loss: 0.34838688373565674
# 	TRAINING: cnn[5], Epoch 1200, Accuracy: 0.98828125
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1200
# 	TRAINING: cnn[5], Epoch 1250, Loss: 0.35469210147857666
# 	TRAINING: cnn[5], Epoch 1250, Accuracy: 0.97265625
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1250
# 	TRAINING: cnn[5], Epoch 1300, Loss: 0.3464486598968506
# 	TRAINING: cnn[5], Epoch 1300, Accuracy: 0.98046875
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1300
# 	TRAINING: cnn[5], Epoch 1350, Loss: 0.3444969654083252
# 	TRAINING: cnn[5], Epoch 1350, Accuracy: 0.98828125
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1350
# 	TRAINING: cnn[5], Epoch 1400, Loss: 0.35079583525657654
# 	TRAINING: cnn[5], Epoch 1400, Accuracy: 0.96875
# 	Max accuracy: 0.98828125
# 	Max accuracy epoch: 882
# Checkpoint saved for epoch 1400
# 	TRAINING: cnn[5], Epoch 1450, Loss: 0.3431241810321808
# 	TRAINING: cnn[5], Epoch 1450, Accuracy: 0.98046875
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1450
# 	TRAINING: cnn[5], Epoch 1500, Loss: 0.34164053201675415
# 	TRAINING: cnn[5], Epoch 1500, Accuracy: 0.9921875
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1500
# 	TRAINING: cnn[5], Epoch 1550, Loss: 0.347991406917572
# 	TRAINING: cnn[5], Epoch 1550, Accuracy: 0.97265625
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1550
# 	TRAINING: cnn[5], Epoch 1600, Loss: 0.3405410051345825
# 	TRAINING: cnn[5], Epoch 1600, Accuracy: 0.984375
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1600
# 	TRAINING: cnn[5], Epoch 1650, Loss: 0.3391020894050598
# 	TRAINING: cnn[5], Epoch 1650, Accuracy: 0.9921875
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1650
# 	TRAINING: cnn[5], Epoch 1700, Loss: 0.34579452872276306
# 	TRAINING: cnn[5], Epoch 1700, Accuracy: 0.97265625
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1700
# 	TRAINING: cnn[5], Epoch 1750, Loss: 0.33869677782058716
# 	TRAINING: cnn[5], Epoch 1750, Accuracy: 0.984375
# 	Max accuracy: 0.9921875
# 	Max accuracy epoch: 1428
# Checkpoint saved for epoch 1750
# 	TRAINING: cnn[5], Epoch 1800, Loss: 0.3377210199832916
# 	TRAINING: cnn[5], Epoch 1800, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 1800
# 	TRAINING: cnn[5], Epoch 1850, Loss: 0.3424220383167267
# 	TRAINING: cnn[5], Epoch 1850, Accuracy: 0.97265625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 1850
# 	TRAINING: cnn[5], Epoch 1900, Loss: 0.33698028326034546
# 	TRAINING: cnn[5], Epoch 1900, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 1900
# 	TRAINING: cnn[5], Epoch 1950, Loss: 0.33546605706214905
# 	TRAINING: cnn[5], Epoch 1950, Accuracy: 0.9921875
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 1950
# 	TRAINING: cnn[5], Epoch 2000, Loss: 0.34189245104789734
# 	TRAINING: cnn[5], Epoch 2000, Accuracy: 0.97265625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2000
# 	TRAINING: cnn[5], Epoch 2050, Loss: 0.335858017206192
# 	TRAINING: cnn[5], Epoch 2050, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2050
# 	TRAINING: cnn[5], Epoch 2100, Loss: 0.3341555595397949
# 	TRAINING: cnn[5], Epoch 2100, Accuracy: 0.9921875
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2100
# 	TRAINING: cnn[5], Epoch 2150, Loss: 0.3392674922943115
# 	TRAINING: cnn[5], Epoch 2150, Accuracy: 0.97265625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2150
# 	TRAINING: cnn[5], Epoch 2200, Loss: 0.3345070481300354
# 	TRAINING: cnn[5], Epoch 2200, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2200
# 	TRAINING: cnn[5], Epoch 2250, Loss: 0.3334459364414215
# 	TRAINING: cnn[5], Epoch 2250, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2250
# 	TRAINING: cnn[5], Epoch 2300, Loss: 0.3383297920227051
# 	TRAINING: cnn[5], Epoch 2300, Accuracy: 0.97265625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2300
# 	TRAINING: cnn[5], Epoch 2350, Loss: 0.3341602087020874
# 	TRAINING: cnn[5], Epoch 2350, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2350
# 	TRAINING: cnn[5], Epoch 2400, Loss: 0.3324257731437683
# 	TRAINING: cnn[5], Epoch 2400, Accuracy: 0.98828125
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2400
# 	TRAINING: cnn[5], Epoch 2450, Loss: 0.3362719416618347
# 	TRAINING: cnn[5], Epoch 2450, Accuracy: 0.97265625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2450
# 	TRAINING: cnn[5], Epoch 2500, Loss: 0.333151251077652
# 	TRAINING: cnn[5], Epoch 2500, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2500
# 	TRAINING: cnn[5], Epoch 2550, Loss: 0.33141815662384033
# 	TRAINING: cnn[5], Epoch 2550, Accuracy: 0.9921875
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2550
# 	TRAINING: cnn[5], Epoch 2600, Loss: 0.335224449634552
# 	TRAINING: cnn[5], Epoch 2600, Accuracy: 0.9765625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2600
# 	TRAINING: cnn[5], Epoch 2650, Loss: 0.3321496546268463
# 	TRAINING: cnn[5], Epoch 2650, Accuracy: 0.984375
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2650
# 	TRAINING: cnn[5], Epoch 2700, Loss: 0.3304659128189087
# 	TRAINING: cnn[5], Epoch 2700, Accuracy: 0.9921875
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2700
# 	TRAINING: cnn[5], Epoch 2750, Loss: 0.33410409092903137
# 	TRAINING: cnn[5], Epoch 2750, Accuracy: 0.9765625
# 	Max accuracy: 0.99609375
# 	Max accuracy epoch: 1764
# Checkpoint saved for epoch 2750
# Reached accuracy of 1. Stopping training for "cnn_5".
# Achieved epoch: 2785
#
# Starting training for "cnn_4"...
# 	No GPU found, running training on CPU...
# 	Recheck CUDA version and if your GPU supports it.
# No checkpoint found at cnn_checkpoint_4.pth. Starting from scratch.
# 	TRAINING: cnn[4], Epoch 50, Loss: 0.6735848188400269
# 	TRAINING: cnn[4], Epoch 50, Accuracy: 0.57421875
# 	Max accuracy: 0.58984375
# 	Max accuracy epoch: 9
# Checkpoint saved for epoch 50
# 	TRAINING: cnn[4], Epoch 100, Loss: 0.672957181930542
# 	TRAINING: cnn[4], Epoch 100, Accuracy: 0.58203125
# 	Max accuracy: 0.58984375
# 	Max accuracy epoch: 9
# Checkpoint saved for epoch 100
# 	TRAINING: cnn[4], Epoch 150, Loss: 0.6719635725021362
# 	TRAINING: cnn[4], Epoch 150, Accuracy: 0.58984375
# 	Max accuracy: 0.58984375
# 	Max accuracy epoch: 9
# Checkpoint saved for epoch 150
# 	TRAINING: cnn[4], Epoch 200, Loss: 0.6680330634117126
# 	TRAINING: cnn[4], Epoch 200, Accuracy: 0.62890625
# 	Max accuracy: 0.62890625
# 	Max accuracy epoch: 200
# Checkpoint saved for epoch 200
# 	TRAINING: cnn[4], Epoch 250, Loss: 0.658231258392334
# 	TRAINING: cnn[4], Epoch 250, Accuracy: 0.60546875
# 	Max accuracy: 0.6484375
# 	Max accuracy epoch: 207
# Checkpoint saved for epoch 250
# 	TRAINING: cnn[4], Epoch 300, Loss: 0.6465076208114624
# 	TRAINING: cnn[4], Epoch 300, Accuracy: 0.671875
# 	Max accuracy: 0.6875
# 	Max accuracy epoch: 299
# Checkpoint saved for epoch 300
# 	TRAINING: cnn[4], Epoch 350, Loss: 0.6314995288848877
# 	TRAINING: cnn[4], Epoch 350, Accuracy: 0.6796875
# 	Max accuracy: 0.69921875
# 	Max accuracy epoch: 320
# Checkpoint saved for epoch 350
# 	TRAINING: cnn[4], Epoch 400, Loss: 0.6244233250617981
# 	TRAINING: cnn[4], Epoch 400, Accuracy: 0.671875
# 	Max accuracy: 0.69921875
# 	Max accuracy epoch: 320
# Checkpoint saved for epoch 400
# 	TRAINING: cnn[4], Epoch 450, Loss: 0.6237408518791199
# 	TRAINING: cnn[4], Epoch 450, Accuracy: 0.640625
# 	Max accuracy: 0.69921875
# 	Max accuracy epoch: 320
# Checkpoint saved for epoch 450
# 	TRAINING: cnn[4], Epoch 500, Loss: 0.6147996783256531
# 	TRAINING: cnn[4], Epoch 500, Accuracy: 0.6953125
# 	Max accuracy: 0.703125
# 	Max accuracy epoch: 496
# Checkpoint saved for epoch 500
# 	TRAINING: cnn[4], Epoch 550, Loss: 0.6065119504928589
# 	TRAINING: cnn[4], Epoch 550, Accuracy: 0.70703125
# 	Max accuracy: 0.70703125
# 	Max accuracy epoch: 544
# Checkpoint saved for epoch 550
# 	TRAINING: cnn[4], Epoch 600, Loss: 0.6075083017349243
# 	TRAINING: cnn[4], Epoch 600, Accuracy: 0.66015625
# 	Max accuracy: 0.71484375
# 	Max accuracy epoch: 599
# Checkpoint saved for epoch 600
# 	TRAINING: cnn[4], Epoch 650, Loss: 0.5951833724975586
# 	TRAINING: cnn[4], Epoch 650, Accuracy: 0.69140625
# 	Max accuracy: 0.73828125
# 	Max accuracy epoch: 641
# Checkpoint saved for epoch 650
# 	TRAINING: cnn[4], Epoch 700, Loss: 0.5864354968070984
# 	TRAINING: cnn[4], Epoch 700, Accuracy: 0.70703125
# 	Max accuracy: 0.76171875
# 	Max accuracy epoch: 679
# Checkpoint saved for epoch 700
# 	TRAINING: cnn[4], Epoch 750, Loss: 0.5891842842102051
# 	TRAINING: cnn[4], Epoch 750, Accuracy: 0.71875
# 	Max accuracy: 0.76953125
# 	Max accuracy epoch: 721
# Checkpoint saved for epoch 750
# 	TRAINING: cnn[4], Epoch 800, Loss: 0.5760290622711182
# 	TRAINING: cnn[4], Epoch 800, Accuracy: 0.7265625
# 	Max accuracy: 0.79296875
# 	Max accuracy epoch: 779
# Checkpoint saved for epoch 800
# 	TRAINING: cnn[4], Epoch 850, Loss: 0.567474901676178
# 	TRAINING: cnn[4], Epoch 850, Accuracy: 0.73046875
# 	Max accuracy: 0.8125
# 	Max accuracy epoch: 841
# Checkpoint saved for epoch 850
# 	TRAINING: cnn[4], Epoch 900, Loss: 0.5733126401901245
# 	TRAINING: cnn[4], Epoch 900, Accuracy: 0.734375
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 900
# 	TRAINING: cnn[4], Epoch 950, Loss: 0.5581761598587036
# 	TRAINING: cnn[4], Epoch 950, Accuracy: 0.75390625
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 950
# 	TRAINING: cnn[4], Epoch 1000, Loss: 0.5490292906761169
# 	TRAINING: cnn[4], Epoch 1000, Accuracy: 0.76953125
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1000
# 	TRAINING: cnn[4], Epoch 1050, Loss: 0.5580730438232422
# 	TRAINING: cnn[4], Epoch 1050, Accuracy: 0.74609375
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1050
# 	TRAINING: cnn[4], Epoch 1100, Loss: 0.5427814722061157
# 	TRAINING: cnn[4], Epoch 1100, Accuracy: 0.76953125
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1100
# 	TRAINING: cnn[4], Epoch 1150, Loss: 0.5328591465950012
# 	TRAINING: cnn[4], Epoch 1150, Accuracy: 0.78125
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1150
# 	TRAINING: cnn[4], Epoch 1200, Loss: 0.5449292659759521
# 	TRAINING: cnn[4], Epoch 1200, Accuracy: 0.75
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1200
# 	TRAINING: cnn[4], Epoch 1250, Loss: 0.5294952392578125
# 	TRAINING: cnn[4], Epoch 1250, Accuracy: 0.78515625
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1250
# 	TRAINING: cnn[4], Epoch 1300, Loss: 0.5192019939422607
# 	TRAINING: cnn[4], Epoch 1300, Accuracy: 0.80078125
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1300
# 	TRAINING: cnn[4], Epoch 1350, Loss: 0.5347591042518616
# 	TRAINING: cnn[4], Epoch 1350, Accuracy: 0.75
# 	Max accuracy: 0.8203125
# 	Max accuracy epoch: 853
# Checkpoint saved for epoch 1350
# 	TRAINING: cnn[4], Epoch 1400, Loss: 0.5180391669273376
# 	TRAINING: cnn[4], Epoch 1400, Accuracy: 0.79296875
# 	Max accuracy: 0.828125
# 	Max accuracy epoch: 1399
# Checkpoint saved for epoch 1400
# 	TRAINING: cnn[4], Epoch 1450, Loss: 0.5097033381462097
# 	TRAINING: cnn[4], Epoch 1450, Accuracy: 0.81640625
# 	Max accuracy: 0.84375
# 	Max accuracy epoch: 1441
# Checkpoint saved for epoch 1450
# 	TRAINING: cnn[4], Epoch 1500, Loss: 0.519117534160614
# 	TRAINING: cnn[4], Epoch 1500, Accuracy: 0.76171875
# 	Max accuracy: 0.859375
# 	Max accuracy epoch: 1489
# Checkpoint saved for epoch 1500
# 	TRAINING: cnn[4], Epoch 1550, Loss: 0.5124194622039795
# 	TRAINING: cnn[4], Epoch 1550, Accuracy: 0.78515625
# 	Max accuracy: 0.86328125
# 	Max accuracy epoch: 1525
# Checkpoint saved for epoch 1550
# 	TRAINING: cnn[4], Epoch 1600, Loss: 0.5016400218009949
# 	TRAINING: cnn[4], Epoch 1600, Accuracy: 0.8203125
# 	Max accuracy: 0.8671875
# 	Max accuracy epoch: 1555
# Checkpoint saved for epoch 1600
# 	TRAINING: cnn[4], Epoch 1650, Loss: 0.5095342993736267
# 	TRAINING: cnn[4], Epoch 1650, Accuracy: 0.78515625
# 	Max accuracy: 0.87109375
# 	Max accuracy epoch: 1627
# Checkpoint saved for epoch 1650
# 	TRAINING: cnn[4], Epoch 1700, Loss: 0.5034167766571045
# 	TRAINING: cnn[4], Epoch 1700, Accuracy: 0.796875
# 	Max accuracy: 0.87109375
# 	Max accuracy epoch: 1627
# Checkpoint saved for epoch 1700
# 	TRAINING: cnn[4], Epoch 1750, Loss: 0.4924919307231903
# 	TRAINING: cnn[4], Epoch 1750, Accuracy: 0.82421875
# 	Max accuracy: 0.875
# 	Max accuracy epoch: 1723
# Checkpoint saved for epoch 1750
# 	TRAINING: cnn[4], Epoch 1800, Loss: 0.5037716627120972
# 	TRAINING: cnn[4], Epoch 1800, Accuracy: 0.78515625
# 	Max accuracy: 0.875
# 	Max accuracy epoch: 1723
# Checkpoint saved for epoch 1800
# 	TRAINING: cnn[4], Epoch 1850, Loss: 0.4944137930870056
# 	TRAINING: cnn[4], Epoch 1850, Accuracy: 0.8125
# 	Max accuracy: 0.875
# 	Max accuracy epoch: 1723
# Checkpoint saved for epoch 1850
# 	TRAINING: cnn[4], Epoch 1900, Loss: 0.48457375168800354
# 	TRAINING: cnn[4], Epoch 1900, Accuracy: 0.82421875
# 	Max accuracy: 0.87890625
# 	Max accuracy epoch: 1873
# Checkpoint saved for epoch 1900
# 	TRAINING: cnn[4], Epoch 1950, Loss: 0.4934588074684143
# 	TRAINING: cnn[4], Epoch 1950, Accuracy: 0.80078125
# 	Max accuracy: 0.8828125
# 	Max accuracy epoch: 1921
# Checkpoint saved for epoch 1950
# 	TRAINING: cnn[4], Epoch 2000, Loss: 0.48823824524879456
# 	TRAINING: cnn[4], Epoch 2000, Accuracy: 0.81640625
# 	Max accuracy: 0.8828125
# 	Max accuracy epoch: 1921
# Checkpoint saved for epoch 2000
# 	TRAINING: cnn[4], Epoch 2050, Loss: 0.47768163681030273
# 	TRAINING: cnn[4], Epoch 2050, Accuracy: 0.83203125
# 	Max accuracy: 0.8828125
# 	Max accuracy epoch: 1921
# Checkpoint saved for epoch 2050
# 	TRAINING: cnn[4], Epoch 2100, Loss: 0.48574620485305786
# 	TRAINING: cnn[4], Epoch 2100, Accuracy: 0.8046875
# 	Max accuracy: 0.8828125
# 	Max accuracy epoch: 1921
# Checkpoint saved for epoch 2100
# 	TRAINING: cnn[4], Epoch 2150, Loss: 0.48292338848114014
# 	TRAINING: cnn[4], Epoch 2150, Accuracy: 0.81640625
# 	Max accuracy: 0.89453125
# 	Max accuracy epoch: 2107
# Checkpoint saved for epoch 2150
# 	TRAINING: cnn[4], Epoch 2200, Loss: 0.4717584252357483
# 	TRAINING: cnn[4], Epoch 2200, Accuracy: 0.8359375
# 	Max accuracy: 0.8984375
# 	Max accuracy epoch: 2179
# Checkpoint saved for epoch 2200
# 	TRAINING: cnn[4], Epoch 2250, Loss: 0.4795495867729187
# 	TRAINING: cnn[4], Epoch 2250, Accuracy: 0.8125
# 	Max accuracy: 0.8984375
# 	Max accuracy epoch: 2179
# Checkpoint saved for epoch 2250
# 	TRAINING: cnn[4], Epoch 2300, Loss: 0.47771894931793213
# 	TRAINING: cnn[4], Epoch 2300, Accuracy: 0.8203125
# 	Max accuracy: 0.8984375
# 	Max accuracy epoch: 2179
# Checkpoint saved for epoch 2300
# 	TRAINING: cnn[4], Epoch 2350, Loss: 0.4657506048679352
# 	TRAINING: cnn[4], Epoch 2350, Accuracy: 0.8359375
# 	Max accuracy: 0.8984375
# 	Max accuracy epoch: 2179
# Checkpoint saved for epoch 2350
# 	TRAINING: cnn[4], Epoch 2400, Loss: 0.4735140800476074
# 	TRAINING: cnn[4], Epoch 2400, Accuracy: 0.828125
# 	Max accuracy: 0.8984375
# 	Max accuracy epoch: 2179
# Checkpoint saved for epoch 2400
# 	TRAINING: cnn[4], Epoch 2450, Loss: 0.4724901616573334
# 	TRAINING: cnn[4], Epoch 2450, Accuracy: 0.8203125
# 	Max accuracy: 0.90234375
# 	Max accuracy epoch: 2419
# Checkpoint saved for epoch 2450
# 	TRAINING: cnn[4], Epoch 2500, Loss: 0.4627687931060791
# 	TRAINING: cnn[4], Epoch 2500, Accuracy: 0.8359375
# 	Max accuracy: 0.91015625
# 	Max accuracy epoch: 2473
# Checkpoint saved for epoch 2500
# 	TRAINING: cnn[4], Epoch 2550, Loss: 0.46463480591773987
# 	TRAINING: cnn[4], Epoch 2550, Accuracy: 0.83203125
# 	Max accuracy: 0.9140625
# 	Max accuracy epoch: 2503
# Checkpoint saved for epoch 2550
# 	TRAINING: cnn[4], Epoch 2600, Loss: 0.47005972266197205
# 	TRAINING: cnn[4], Epoch 2600, Accuracy: 0.81640625
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2600
# 	TRAINING: cnn[4], Epoch 2650, Loss: 0.45421141386032104
# 	TRAINING: cnn[4], Epoch 2650, Accuracy: 0.84765625
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2650
# 	TRAINING: cnn[4], Epoch 2700, Loss: 0.46373116970062256
# 	TRAINING: cnn[4], Epoch 2700, Accuracy: 0.83203125
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2700
# 	TRAINING: cnn[4], Epoch 2750, Loss: 0.4618229269981384
# 	TRAINING: cnn[4], Epoch 2750, Accuracy: 0.8359375
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2750
# 	TRAINING: cnn[4], Epoch 2800, Loss: 0.4511754512786865
# 	TRAINING: cnn[4], Epoch 2800, Accuracy: 0.85546875
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2800
# 	TRAINING: cnn[4], Epoch 2850, Loss: 0.4589664041996002
# 	TRAINING: cnn[4], Epoch 2850, Accuracy: 0.83984375
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2850
# 	TRAINING: cnn[4], Epoch 2900, Loss: 0.4590057134628296
# 	TRAINING: cnn[4], Epoch 2900, Accuracy: 0.83984375
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2900
# 	TRAINING: cnn[4], Epoch 2950, Loss: 0.446102499961853
# 	TRAINING: cnn[4], Epoch 2950, Accuracy: 0.859375
# 	Max accuracy: 0.91796875
# 	Max accuracy epoch: 2551
# Checkpoint saved for epoch 2950
# 	TRAINING: cnn[4], Epoch 3000, Loss: 0.4538843035697937
# 	TRAINING: cnn[4], Epoch 3000, Accuracy: 0.83984375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3000
# 	TRAINING: cnn[4], Epoch 3050, Loss: 0.4521460235118866
# 	TRAINING: cnn[4], Epoch 3050, Accuracy: 0.8515625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3050
# 	TRAINING: cnn[4], Epoch 3100, Loss: 0.44051462411880493
# 	TRAINING: cnn[4], Epoch 3100, Accuracy: 0.875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3100
# 	TRAINING: cnn[4], Epoch 3150, Loss: 0.4519638121128082
# 	TRAINING: cnn[4], Epoch 3150, Accuracy: 0.84765625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3150
# 	TRAINING: cnn[4], Epoch 3200, Loss: 0.4499542713165283
# 	TRAINING: cnn[4], Epoch 3200, Accuracy: 0.8515625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3200
# 	TRAINING: cnn[4], Epoch 3250, Loss: 0.43740081787109375
# 	TRAINING: cnn[4], Epoch 3250, Accuracy: 0.87890625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3250
# 	TRAINING: cnn[4], Epoch 3300, Loss: 0.4472733736038208
# 	TRAINING: cnn[4], Epoch 3300, Accuracy: 0.84765625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3300
# 	TRAINING: cnn[4], Epoch 3350, Loss: 0.44548657536506653
# 	TRAINING: cnn[4], Epoch 3350, Accuracy: 0.859375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3350
# 	TRAINING: cnn[4], Epoch 3400, Loss: 0.43229779601097107
# 	TRAINING: cnn[4], Epoch 3400, Accuracy: 0.8828125
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3400
# 	TRAINING: cnn[4], Epoch 3450, Loss: 0.44519323110580444
# 	TRAINING: cnn[4], Epoch 3450, Accuracy: 0.85546875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3450
# 	TRAINING: cnn[4], Epoch 3500, Loss: 0.44056567549705505
# 	TRAINING: cnn[4], Epoch 3500, Accuracy: 0.86328125
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3500
# 	TRAINING: cnn[4], Epoch 3550, Loss: 0.42840415239334106
# 	TRAINING: cnn[4], Epoch 3550, Accuracy: 0.88671875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3550
# 	TRAINING: cnn[4], Epoch 3600, Loss: 0.44255316257476807
# 	TRAINING: cnn[4], Epoch 3600, Accuracy: 0.85546875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3600
# 	TRAINING: cnn[4], Epoch 3650, Loss: 0.4367392957210541
# 	TRAINING: cnn[4], Epoch 3650, Accuracy: 0.87109375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3650
# 	TRAINING: cnn[4], Epoch 3700, Loss: 0.4240058660507202
# 	TRAINING: cnn[4], Epoch 3700, Accuracy: 0.89453125
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3700
# 	TRAINING: cnn[4], Epoch 3750, Loss: 0.4394650161266327
# 	TRAINING: cnn[4], Epoch 3750, Accuracy: 0.859375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3750
# 	TRAINING: cnn[4], Epoch 3800, Loss: 0.43260657787323
# 	TRAINING: cnn[4], Epoch 3800, Accuracy: 0.875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3800
# 	TRAINING: cnn[4], Epoch 3850, Loss: 0.42005112767219543
# 	TRAINING: cnn[4], Epoch 3850, Accuracy: 0.8984375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3850
# 	TRAINING: cnn[4], Epoch 3900, Loss: 0.43819740414619446
# 	TRAINING: cnn[4], Epoch 3900, Accuracy: 0.859375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3900
# 	TRAINING: cnn[4], Epoch 3950, Loss: 0.42850378155708313
# 	TRAINING: cnn[4], Epoch 3950, Accuracy: 0.87890625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 3950
# 	TRAINING: cnn[4], Epoch 4000, Loss: 0.4160360097885132
# 	TRAINING: cnn[4], Epoch 4000, Accuracy: 0.90625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4000
# 	TRAINING: cnn[4], Epoch 4050, Loss: 0.43914708495140076
# 	TRAINING: cnn[4], Epoch 4050, Accuracy: 0.859375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4050
# 	TRAINING: cnn[4], Epoch 4100, Loss: 0.4237230122089386
# 	TRAINING: cnn[4], Epoch 4100, Accuracy: 0.88671875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4100
# 	TRAINING: cnn[4], Epoch 4150, Loss: 0.4123927056789398
# 	TRAINING: cnn[4], Epoch 4150, Accuracy: 0.90625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4150
# 	TRAINING: cnn[4], Epoch 4200, Loss: 0.436190664768219
# 	TRAINING: cnn[4], Epoch 4200, Accuracy: 0.86328125
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4200
# 	TRAINING: cnn[4], Epoch 4250, Loss: 0.42096608877182007
# 	TRAINING: cnn[4], Epoch 4250, Accuracy: 0.88671875
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4250
# 	TRAINING: cnn[4], Epoch 4300, Loss: 0.40938976407051086
# 	TRAINING: cnn[4], Epoch 4300, Accuracy: 0.91015625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4300
# 	TRAINING: cnn[4], Epoch 4350, Loss: 0.4394780695438385
# 	TRAINING: cnn[4], Epoch 4350, Accuracy: 0.859375
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4350
# 	TRAINING: cnn[4], Epoch 4400, Loss: 0.41925784945487976
# 	TRAINING: cnn[4], Epoch 4400, Accuracy: 0.89453125
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4400
# 	TRAINING: cnn[4], Epoch 4450, Loss: 0.4023107886314392
# 	TRAINING: cnn[4], Epoch 4450, Accuracy: 0.9140625
# 	Max accuracy: 0.921875
# 	Max accuracy epoch: 2983
# Checkpoint saved for epoch 4450
# 	TRAINING: cnn[4], Epoch 4500, Loss: 0.42640361189842224
# 	TRAINING: cnn[4], Epoch 4500, Accuracy: 0.875
# 	Max accuracy: 0.92578125
# 	Max accuracy epoch: 4495
# Checkpoint saved for epoch 4500
# 	TRAINING: cnn[4], Epoch 4550, Loss: 0.41454240679740906
# 	TRAINING: cnn[4], Epoch 4550, Accuracy: 0.89453125
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4550
# 	TRAINING: cnn[4], Epoch 4600, Loss: 0.4002929627895355
# 	TRAINING: cnn[4], Epoch 4600, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4600
# 	TRAINING: cnn[4], Epoch 4650, Loss: 0.4288632571697235
# 	TRAINING: cnn[4], Epoch 4650, Accuracy: 0.875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4650
# 	TRAINING: cnn[4], Epoch 4700, Loss: 0.4094551205635071
# 	TRAINING: cnn[4], Epoch 4700, Accuracy: 0.8984375
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4700
# 	TRAINING: cnn[4], Epoch 4750, Loss: 0.4036577045917511
# 	TRAINING: cnn[4], Epoch 4750, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4750
# 	TRAINING: cnn[4], Epoch 4800, Loss: 0.431395024061203
# 	TRAINING: cnn[4], Epoch 4800, Accuracy: 0.8671875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4800
# 	TRAINING: cnn[4], Epoch 4850, Loss: 0.40763548016548157
# 	TRAINING: cnn[4], Epoch 4850, Accuracy: 0.8984375
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4850
# 	TRAINING: cnn[4], Epoch 4900, Loss: 0.3978762626647949
# 	TRAINING: cnn[4], Epoch 4900, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4900
# 	TRAINING: cnn[4], Epoch 4950, Loss: 0.43005484342575073
# 	TRAINING: cnn[4], Epoch 4950, Accuracy: 0.87109375
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 4950
# 	TRAINING: cnn[4], Epoch 5000, Loss: 0.40561485290527344
# 	TRAINING: cnn[4], Epoch 5000, Accuracy: 0.90234375
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5000
# 	TRAINING: cnn[4], Epoch 5050, Loss: 0.39603325724601746
# 	TRAINING: cnn[4], Epoch 5050, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5050
# 	TRAINING: cnn[4], Epoch 5100, Loss: 0.42761513590812683
# 	TRAINING: cnn[4], Epoch 5100, Accuracy: 0.875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5100
# 	TRAINING: cnn[4], Epoch 5150, Loss: 0.4040786921977997
# 	TRAINING: cnn[4], Epoch 5150, Accuracy: 0.90234375
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5150
# 	TRAINING: cnn[4], Epoch 5200, Loss: 0.3945314884185791
# 	TRAINING: cnn[4], Epoch 5200, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5200
# 	TRAINING: cnn[4], Epoch 5250, Loss: 0.4253966510295868
# 	TRAINING: cnn[4], Epoch 5250, Accuracy: 0.875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5250
# 	TRAINING: cnn[4], Epoch 5300, Loss: 0.4020603597164154
# 	TRAINING: cnn[4], Epoch 5300, Accuracy: 0.90625
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5300
# 	TRAINING: cnn[4], Epoch 5350, Loss: 0.3928999602794647
# 	TRAINING: cnn[4], Epoch 5350, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5350
# 	TRAINING: cnn[4], Epoch 5400, Loss: 0.42359915375709534
# 	TRAINING: cnn[4], Epoch 5400, Accuracy: 0.8828125
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5400
# 	TRAINING: cnn[4], Epoch 5450, Loss: 0.40103915333747864
# 	TRAINING: cnn[4], Epoch 5450, Accuracy: 0.90625
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5450
# 	TRAINING: cnn[4], Epoch 5500, Loss: 0.3922148644924164
# 	TRAINING: cnn[4], Epoch 5500, Accuracy: 0.91796875
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5500
# 	TRAINING: cnn[4], Epoch 5550, Loss: 0.421021968126297
# 	TRAINING: cnn[4], Epoch 5550, Accuracy: 0.8828125
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5550
# 	TRAINING: cnn[4], Epoch 5600, Loss: 0.3994746208190918
# 	TRAINING: cnn[4], Epoch 5600, Accuracy: 0.90625
# 	Max accuracy: 0.93359375
# 	Max accuracy epoch: 4507
# Checkpoint saved for epoch 5600
# 	TRAINING: cnn[4], Epoch 5650, Loss: 0.3891086280345917
# 	TRAINING: cnn[4], Epoch 5650, Accuracy: 0.93359375
# 	Max accuracy: 0.9375
# 	Max accuracy epoch: 5647
# Checkpoint saved for epoch 5650
# 	TRAINING: cnn[4], Epoch 5700, Loss: 0.3885325491428375
# 	TRAINING: cnn[4], Epoch 5700, Accuracy: 0.9296875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 5700
# 	TRAINING: cnn[4], Epoch 5750, Loss: 0.3802981674671173
# 	TRAINING: cnn[4], Epoch 5750, Accuracy: 0.95703125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 5750
# 	TRAINING: cnn[4], Epoch 5800, Loss: 0.3795229196548462
# 	TRAINING: cnn[4], Epoch 5800, Accuracy: 0.9609375
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 5800
# 	TRAINING: cnn[4], Epoch 5850, Loss: 0.3843565881252289
# 	TRAINING: cnn[4], Epoch 5850, Accuracy: 0.9296875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 5850
# 	TRAINING: cnn[4], Epoch 5900, Loss: 0.381277471780777
# 	TRAINING: cnn[4], Epoch 5900, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 5900
# 	TRAINING: cnn[4], Epoch 5950, Loss: 0.3844979405403137
# 	TRAINING: cnn[4], Epoch 5950, Accuracy: 0.9296875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 5950
# 	TRAINING: cnn[4], Epoch 6000, Loss: 0.379928320646286
# 	TRAINING: cnn[4], Epoch 6000, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6000
# 	TRAINING: cnn[4], Epoch 6050, Loss: 0.38419070839881897
# 	TRAINING: cnn[4], Epoch 6050, Accuracy: 0.92578125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6050
# 	TRAINING: cnn[4], Epoch 6100, Loss: 0.37861868739128113
# 	TRAINING: cnn[4], Epoch 6100, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6100
# 	TRAINING: cnn[4], Epoch 6150, Loss: 0.38383033871650696
# 	TRAINING: cnn[4], Epoch 6150, Accuracy: 0.9296875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6150
# 	TRAINING: cnn[4], Epoch 6200, Loss: 0.3773455023765564
# 	TRAINING: cnn[4], Epoch 6200, Accuracy: 0.94921875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6200
# 	TRAINING: cnn[4], Epoch 6250, Loss: 0.38376301527023315
# 	TRAINING: cnn[4], Epoch 6250, Accuracy: 0.92578125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6250
# 	TRAINING: cnn[4], Epoch 6300, Loss: 0.3761233389377594
# 	TRAINING: cnn[4], Epoch 6300, Accuracy: 0.94921875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6300
# 	TRAINING: cnn[4], Epoch 6350, Loss: 0.383391410112381
# 	TRAINING: cnn[4], Epoch 6350, Accuracy: 0.92578125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6350
# 	TRAINING: cnn[4], Epoch 6400, Loss: 0.37510237097740173
# 	TRAINING: cnn[4], Epoch 6400, Accuracy: 0.94921875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6400
# 	TRAINING: cnn[4], Epoch 6450, Loss: 0.3826052248477936
# 	TRAINING: cnn[4], Epoch 6450, Accuracy: 0.9296875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6450
# 	TRAINING: cnn[4], Epoch 6500, Loss: 0.3744163513183594
# 	TRAINING: cnn[4], Epoch 6500, Accuracy: 0.94921875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6500
# 	TRAINING: cnn[4], Epoch 6550, Loss: 0.38132843375205994
# 	TRAINING: cnn[4], Epoch 6550, Accuracy: 0.93359375
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6550
# 	TRAINING: cnn[4], Epoch 6600, Loss: 0.37431755661964417
# 	TRAINING: cnn[4], Epoch 6600, Accuracy: 0.94921875
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6600
# 	TRAINING: cnn[4], Epoch 6650, Loss: 0.3795461058616638
# 	TRAINING: cnn[4], Epoch 6650, Accuracy: 0.9375
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6650
# 	TRAINING: cnn[4], Epoch 6700, Loss: 0.37515687942504883
# 	TRAINING: cnn[4], Epoch 6700, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6700
# 	TRAINING: cnn[4], Epoch 6750, Loss: 0.3776312470436096
# 	TRAINING: cnn[4], Epoch 6750, Accuracy: 0.9375
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6750
# 	TRAINING: cnn[4], Epoch 6800, Loss: 0.37454426288604736
# 	TRAINING: cnn[4], Epoch 6800, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6800
# 	TRAINING: cnn[4], Epoch 6850, Loss: 0.3769811987876892
# 	TRAINING: cnn[4], Epoch 6850, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6850
# 	TRAINING: cnn[4], Epoch 6900, Loss: 0.3739854395389557
# 	TRAINING: cnn[4], Epoch 6900, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6900
# 	TRAINING: cnn[4], Epoch 6950, Loss: 0.37648171186447144
# 	TRAINING: cnn[4], Epoch 6950, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 6950
# 	TRAINING: cnn[4], Epoch 7000, Loss: 0.3734391927719116
# 	TRAINING: cnn[4], Epoch 7000, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7000
# 	TRAINING: cnn[4], Epoch 7050, Loss: 0.3758580684661865
# 	TRAINING: cnn[4], Epoch 7050, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7050
# 	TRAINING: cnn[4], Epoch 7100, Loss: 0.37309637665748596
# 	TRAINING: cnn[4], Epoch 7100, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7100
# 	TRAINING: cnn[4], Epoch 7150, Loss: 0.37494146823883057
# 	TRAINING: cnn[4], Epoch 7150, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7150
# 	TRAINING: cnn[4], Epoch 7200, Loss: 0.37288719415664673
# 	TRAINING: cnn[4], Epoch 7200, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7200
# 	TRAINING: cnn[4], Epoch 7250, Loss: 0.3741547465324402
# 	TRAINING: cnn[4], Epoch 7250, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7250
# 	TRAINING: cnn[4], Epoch 7300, Loss: 0.3725740611553192
# 	TRAINING: cnn[4], Epoch 7300, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7300
# 	TRAINING: cnn[4], Epoch 7350, Loss: 0.37348249554634094
# 	TRAINING: cnn[4], Epoch 7350, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7350
# 	TRAINING: cnn[4], Epoch 7400, Loss: 0.37227827310562134
# 	TRAINING: cnn[4], Epoch 7400, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7400
# 	TRAINING: cnn[4], Epoch 7450, Loss: 0.3728403151035309
# 	TRAINING: cnn[4], Epoch 7450, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7450
# 	TRAINING: cnn[4], Epoch 7500, Loss: 0.3719868063926697
# 	TRAINING: cnn[4], Epoch 7500, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7500
# 	TRAINING: cnn[4], Epoch 7550, Loss: 0.3721340000629425
# 	TRAINING: cnn[4], Epoch 7550, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7550
# 	TRAINING: cnn[4], Epoch 7600, Loss: 0.37172579765319824
# 	TRAINING: cnn[4], Epoch 7600, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7600
# 	TRAINING: cnn[4], Epoch 7650, Loss: 0.37182778120040894
# 	TRAINING: cnn[4], Epoch 7650, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7650
# 	TRAINING: cnn[4], Epoch 7700, Loss: 0.37127619981765747
# 	TRAINING: cnn[4], Epoch 7700, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7700
# 	TRAINING: cnn[4], Epoch 7750, Loss: 0.3714047968387604
# 	TRAINING: cnn[4], Epoch 7750, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7750
# 	TRAINING: cnn[4], Epoch 7800, Loss: 0.37091192603111267
# 	TRAINING: cnn[4], Epoch 7800, Accuracy: 0.94140625
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7800
# 	TRAINING: cnn[4], Epoch 7850, Loss: 0.3714698851108551
# 	TRAINING: cnn[4], Epoch 7850, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7850
# 	TRAINING: cnn[4], Epoch 7900, Loss: 0.370035856962204
# 	TRAINING: cnn[4], Epoch 7900, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7900
# 	TRAINING: cnn[4], Epoch 7950, Loss: 0.3712311387062073
# 	TRAINING: cnn[4], Epoch 7950, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 7950
# 	TRAINING: cnn[4], Epoch 8000, Loss: 0.3701953887939453
# 	TRAINING: cnn[4], Epoch 8000, Accuracy: 0.9453125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 8000
# 	TRAINING: cnn[4], Epoch 8050, Loss: 0.3697236478328705
# 	TRAINING: cnn[4], Epoch 8050, Accuracy: 0.95703125
# 	Max accuracy: 0.96484375
# 	Max accuracy epoch: 5691
# Checkpoint saved for epoch 8050
# 	TRAINING: cnn[4], Epoch 8100, Loss: 0.3694811761379242
# 	TRAINING: cnn[4], Epoch 8100, Accuracy: 0.953125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8100
# 	TRAINING: cnn[4], Epoch 8150, Loss: 0.37343621253967285
# 	TRAINING: cnn[4], Epoch 8150, Accuracy: 0.953125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8150
# 	TRAINING: cnn[4], Epoch 8200, Loss: 0.36822354793548584
# 	TRAINING: cnn[4], Epoch 8200, Accuracy: 0.953125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8200
# 	TRAINING: cnn[4], Epoch 8250, Loss: 0.3808026611804962
# 	TRAINING: cnn[4], Epoch 8250, Accuracy: 0.9296875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8250
# 	TRAINING: cnn[4], Epoch 8300, Loss: 0.3648858368396759
# 	TRAINING: cnn[4], Epoch 8300, Accuracy: 0.953125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8300
# 	TRAINING: cnn[4], Epoch 8350, Loss: 0.3730819523334503
# 	TRAINING: cnn[4], Epoch 8350, Accuracy: 0.94140625
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8350
# 	TRAINING: cnn[4], Epoch 8400, Loss: 0.37253138422966003
# 	TRAINING: cnn[4], Epoch 8400, Accuracy: 0.9453125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8400
# 	TRAINING: cnn[4], Epoch 8450, Loss: 0.3720818758010864
# 	TRAINING: cnn[4], Epoch 8450, Accuracy: 0.94921875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8450
# 	TRAINING: cnn[4], Epoch 8500, Loss: 0.3719189167022705
# 	TRAINING: cnn[4], Epoch 8500, Accuracy: 0.9375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8500
# 	TRAINING: cnn[4], Epoch 8550, Loss: 0.37736251950263977
# 	TRAINING: cnn[4], Epoch 8550, Accuracy: 0.93359375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8550
# 	TRAINING: cnn[4], Epoch 8600, Loss: 0.3755282461643219
# 	TRAINING: cnn[4], Epoch 8600, Accuracy: 0.9375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8600
# 	TRAINING: cnn[4], Epoch 8650, Loss: 0.3739432692527771
# 	TRAINING: cnn[4], Epoch 8650, Accuracy: 0.93359375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8650
# 	TRAINING: cnn[4], Epoch 8700, Loss: 0.36234307289123535
# 	TRAINING: cnn[4], Epoch 8700, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8700
# 	TRAINING: cnn[4], Epoch 8750, Loss: 0.3734793961048126
# 	TRAINING: cnn[4], Epoch 8750, Accuracy: 0.94140625
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8750
# 	TRAINING: cnn[4], Epoch 8800, Loss: 0.37445271015167236
# 	TRAINING: cnn[4], Epoch 8800, Accuracy: 0.9375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8800
# 	TRAINING: cnn[4], Epoch 8850, Loss: 0.36242520809173584
# 	TRAINING: cnn[4], Epoch 8850, Accuracy: 0.9609375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8850
# 	TRAINING: cnn[4], Epoch 8900, Loss: 0.3642340898513794
# 	TRAINING: cnn[4], Epoch 8900, Accuracy: 0.95703125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8900
# 	TRAINING: cnn[4], Epoch 8950, Loss: 0.36973655223846436
# 	TRAINING: cnn[4], Epoch 8950, Accuracy: 0.94921875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 8950
# 	TRAINING: cnn[4], Epoch 9000, Loss: 0.37599843740463257
# 	TRAINING: cnn[4], Epoch 9000, Accuracy: 0.93359375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 9000
# 	TRAINING: cnn[4], Epoch 9050, Loss: 0.3686026632785797
# 	TRAINING: cnn[4], Epoch 9050, Accuracy: 0.953125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 9050
# 	TRAINING: cnn[4], Epoch 9100, Loss: 0.3615665137767792
# 	TRAINING: cnn[4], Epoch 9100, Accuracy: 0.95703125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 9100
# 	TRAINING: cnn[4], Epoch 9150, Loss: 0.3685512840747833
# 	TRAINING: cnn[4], Epoch 9150, Accuracy: 0.9453125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 9150
# 	TRAINING: cnn[4], Epoch 9200, Loss: 0.3728698790073395
# 	TRAINING: cnn[4], Epoch 9200, Accuracy: 0.9453125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 9200
# 	TRAINING: cnn[4], Epoch 9250, Loss: 0.3717016279697418
# 	TRAINING: cnn[4], Epoch 9250, Accuracy: 0.9375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 9250
# 	TRAINING: cnn[4], Epoch 9300, Loss: 0.3828732967376709
# 	TRAINING: cnn[4], Epoch 9300, Accuracy: 0.9296875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# ...
# Checkpoint saved for epoch 22600
# 	TRAINING: cnn[4], Epoch 22650, Loss: 0.3698478937149048
# 	TRAINING: cnn[4], Epoch 22650, Accuracy: 0.94140625
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22650
# 	TRAINING: cnn[4], Epoch 22700, Loss: 0.354373961687088
# 	TRAINING: cnn[4], Epoch 22700, Accuracy: 0.95703125
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22700
# 	TRAINING: cnn[4], Epoch 22750, Loss: 0.3484549820423126
# 	TRAINING: cnn[4], Epoch 22750, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22750
# 	TRAINING: cnn[4], Epoch 22800, Loss: 0.3483947813510895
# 	TRAINING: cnn[4], Epoch 22800, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22800
# 	TRAINING: cnn[4], Epoch 22850, Loss: 0.348768949508667
# 	TRAINING: cnn[4], Epoch 22850, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22850
# 	TRAINING: cnn[4], Epoch 22900, Loss: 0.3486011326313019
# 	TRAINING: cnn[4], Epoch 22900, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22900
# 	TRAINING: cnn[4], Epoch 22950, Loss: 0.3485575318336487
# 	TRAINING: cnn[4], Epoch 22950, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 22950
# 	TRAINING: cnn[4], Epoch 23000, Loss: 0.34870287775993347
# 	TRAINING: cnn[4], Epoch 23000, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23000
# 	TRAINING: cnn[4], Epoch 23050, Loss: 0.3484072685241699
# 	TRAINING: cnn[4], Epoch 23050, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23050
# 	TRAINING: cnn[4], Epoch 23100, Loss: 0.34877100586891174
# 	TRAINING: cnn[4], Epoch 23100, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23100
# 	TRAINING: cnn[4], Epoch 23150, Loss: 0.34834298491477966
# 	TRAINING: cnn[4], Epoch 23150, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23150
# 	TRAINING: cnn[4], Epoch 23200, Loss: 0.3487854599952698
# 	TRAINING: cnn[4], Epoch 23200, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23200
# 	TRAINING: cnn[4], Epoch 23250, Loss: 0.348339706659317
# 	TRAINING: cnn[4], Epoch 23250, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23250
# 	TRAINING: cnn[4], Epoch 23300, Loss: 0.34875524044036865
# 	TRAINING: cnn[4], Epoch 23300, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23300
# 	TRAINING: cnn[4], Epoch 23350, Loss: 0.34841838479042053
# 	TRAINING: cnn[4], Epoch 23350, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23350
# 	TRAINING: cnn[4], Epoch 23400, Loss: 0.3486510217189789
# 	TRAINING: cnn[4], Epoch 23400, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23400
# 	TRAINING: cnn[4], Epoch 23450, Loss: 0.34851551055908203
# 	TRAINING: cnn[4], Epoch 23450, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23450
# 	TRAINING: cnn[4], Epoch 23500, Loss: 0.348575234413147
# 	TRAINING: cnn[4], Epoch 23500, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23500
# 	TRAINING: cnn[4], Epoch 23550, Loss: 0.34858861565589905
# 	TRAINING: cnn[4], Epoch 23550, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23550
# 	TRAINING: cnn[4], Epoch 23600, Loss: 0.3485344350337982
# 	TRAINING: cnn[4], Epoch 23600, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23600
# 	TRAINING: cnn[4], Epoch 23650, Loss: 0.3486229181289673
# 	TRAINING: cnn[4], Epoch 23650, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23650
# 	TRAINING: cnn[4], Epoch 23700, Loss: 0.34852471947669983
# 	TRAINING: cnn[4], Epoch 23700, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23700
# 	TRAINING: cnn[4], Epoch 23750, Loss: 0.3486337661743164
# 	TRAINING: cnn[4], Epoch 23750, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23750
# 	TRAINING: cnn[4], Epoch 23800, Loss: 0.3485203981399536
# 	TRAINING: cnn[4], Epoch 23800, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23800
# 	TRAINING: cnn[4], Epoch 23850, Loss: 0.3485967516899109
# 	TRAINING: cnn[4], Epoch 23850, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23850
# 	TRAINING: cnn[4], Epoch 23900, Loss: 0.3485449254512787
# 	TRAINING: cnn[4], Epoch 23900, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23900
# 	TRAINING: cnn[4], Epoch 23950, Loss: 0.34858939051628113
# 	TRAINING: cnn[4], Epoch 23950, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 23950
# 	TRAINING: cnn[4], Epoch 24000, Loss: 0.34854698181152344
# 	TRAINING: cnn[4], Epoch 24000, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24000
# 	TRAINING: cnn[4], Epoch 24050, Loss: 0.3485451638698578
# 	TRAINING: cnn[4], Epoch 24050, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24050
# 	TRAINING: cnn[4], Epoch 24100, Loss: 0.34853994846343994
# 	TRAINING: cnn[4], Epoch 24100, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24100
# 	TRAINING: cnn[4], Epoch 24150, Loss: 0.34851181507110596
# 	TRAINING: cnn[4], Epoch 24150, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24150
# 	TRAINING: cnn[4], Epoch 24200, Loss: 0.3485444188117981
# 	TRAINING: cnn[4], Epoch 24200, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24200
# 	TRAINING: cnn[4], Epoch 24250, Loss: 0.3485497832298279
# 	TRAINING: cnn[4], Epoch 24250, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24250
# 	TRAINING: cnn[4], Epoch 24300, Loss: 0.3497719168663025
# 	TRAINING: cnn[4], Epoch 24300, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24300
# 	TRAINING: cnn[4], Epoch 24350, Loss: 0.34884047508239746
# 	TRAINING: cnn[4], Epoch 24350, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24350
# 	TRAINING: cnn[4], Epoch 24400, Loss: 0.35013508796691895
# 	TRAINING: cnn[4], Epoch 24400, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24400
# 	TRAINING: cnn[4], Epoch 24450, Loss: 0.3489660918712616
# 	TRAINING: cnn[4], Epoch 24450, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24450
# 	TRAINING: cnn[4], Epoch 24500, Loss: 0.3495732843875885
# 	TRAINING: cnn[4], Epoch 24500, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24500
# 	TRAINING: cnn[4], Epoch 24550, Loss: 0.3489287197589874
# 	TRAINING: cnn[4], Epoch 24550, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24550
# 	TRAINING: cnn[4], Epoch 24600, Loss: 0.3493002951145172
# 	TRAINING: cnn[4], Epoch 24600, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24600
# 	TRAINING: cnn[4], Epoch 24650, Loss: 0.34876400232315063
# 	TRAINING: cnn[4], Epoch 24650, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24650
# 	TRAINING: cnn[4], Epoch 24700, Loss: 0.3490828573703766
# 	TRAINING: cnn[4], Epoch 24700, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24700
# 	TRAINING: cnn[4], Epoch 24750, Loss: 0.34874191880226135
# 	TRAINING: cnn[4], Epoch 24750, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24750
# 	TRAINING: cnn[4], Epoch 24800, Loss: 0.3493688702583313
# 	TRAINING: cnn[4], Epoch 24800, Accuracy: 0.96484375
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24800
# 	TRAINING: cnn[4], Epoch 24850, Loss: 0.34857645630836487
# 	TRAINING: cnn[4], Epoch 24850, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24850
# 	TRAINING: cnn[4], Epoch 24900, Loss: 0.3488374352455139
# 	TRAINING: cnn[4], Epoch 24900, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24900
# 	TRAINING: cnn[4], Epoch 24950, Loss: 0.34861260652542114
# 	TRAINING: cnn[4], Epoch 24950, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 24950
# 	TRAINING: cnn[4], Epoch 25000, Loss: 0.34876522421836853
# 	TRAINING: cnn[4], Epoch 25000, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25000
# 	TRAINING: cnn[4], Epoch 25050, Loss: 0.34853941202163696
# 	TRAINING: cnn[4], Epoch 25050, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25050
# 	TRAINING: cnn[4], Epoch 25100, Loss: 0.34858742356300354
# 	TRAINING: cnn[4], Epoch 25100, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25100
# 	TRAINING: cnn[4], Epoch 25150, Loss: 0.34843313694000244
# 	TRAINING: cnn[4], Epoch 25150, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25150
# 	TRAINING: cnn[4], Epoch 25200, Loss: 0.3485341966152191
# 	TRAINING: cnn[4], Epoch 25200, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25200
# 	TRAINING: cnn[4], Epoch 25250, Loss: 0.3482119143009186
# 	TRAINING: cnn[4], Epoch 25250, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25250
# 	TRAINING: cnn[4], Epoch 25300, Loss: 0.3484460115432739
# 	TRAINING: cnn[4], Epoch 25300, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25300
# 	TRAINING: cnn[4], Epoch 25350, Loss: 0.34827858209609985
# 	TRAINING: cnn[4], Epoch 25350, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25350
# 	TRAINING: cnn[4], Epoch 25400, Loss: 0.34839555621147156
# 	TRAINING: cnn[4], Epoch 25400, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25400
# 	TRAINING: cnn[4], Epoch 25450, Loss: 0.3481764495372772
# 	TRAINING: cnn[4], Epoch 25450, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25450
# 	TRAINING: cnn[4], Epoch 25500, Loss: 0.34830886125564575
# 	TRAINING: cnn[4], Epoch 25500, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25500
# 	TRAINING: cnn[4], Epoch 25550, Loss: 0.3483164310455322
# 	TRAINING: cnn[4], Epoch 25550, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25550
# 	TRAINING: cnn[4], Epoch 25600, Loss: 0.3481351435184479
# 	TRAINING: cnn[4], Epoch 25600, Accuracy: 0.96875
# 	Max accuracy: 0.96875
# 	Max accuracy epoch: 8067
# Checkpoint saved for epoch 25600
# Training interrupted. Pausing training...
# Checkpoint saved for last epoch 25640
# 	Final accuracy: 0.96875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 70
#      67 correct = 0
#      68 cnn.train()
# ---> 70 for inputs, labels in dataloaders[i]:
#      71     inputs, labels = inputs.to(device), labels.to(device)
#      72     # Add dimensions for channels and width
#      73     # inputs = inputs.unsqueeze(1).unsqueeze(-1)
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\collate.py:211, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
# --> 211     return [
#     212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\collate.py:212, in <listcomp>(.0)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\collate.py:285, in collate_numpy_array_fn(batch, collate_fn_map)
#     282 if np_str_obj_array_pattern.search(elem.dtype.str) is not None:
#     283     raise TypeError(default_collate_err_msg_format.format(elem.dtype))
# --> 285 return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
#
# File c:\Users\Calvin\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\collate.py:285, in <listcomp>(.0)
#     282 if np_str_obj_array_pattern.search(elem.dtype.str) is not None:
#     283     raise TypeError(default_collate_err_msg_format.format(elem.dtype))
# --> 285 return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing the CNNs
#
# Using the resulting CNNs saved in the .pth files, we test each CNNs using the provided power traces.
#
# Currently the testing data is a subset of the training data. In the future, if we can generate more data, we will be able to use separate datasets.

# %%
# Run evaluation using testing data
# CURRENTLY USING TRAINING DATA TO TEST DATA: use separate dataset in the future
for i in range(7,-1,-1):
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=True)
        cnn.load_state_dict(checkpoint['cnn_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch']
        print(f"Checkpoint loaded. Resuming from epoch {start_epoch}")
        reached_target_acc = checkpoint['reached_acc']
        print(f"Previous reached accuracy: {reached_target_acc}")
        if reached_target_acc != 1:
            print(f"cnn_{i}\" did not reach accuracy of 1, skipping evaluation.\n\n")
            continue
    except FileNotFoundError:
        print(f"No checkpoint found for \"cnn_{i}\". Starting from scratch.")

    cnns[i].eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloaders[i]:
            inputs, labels = inputs.to(device), labels.to(device)
            # Add dimensions for channels and width
            inputs = inputs.unsqueeze(1).unsqueeze(-1)
            outputs = cnns[i](inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f"Accuracy: {100 * correct / total:.2f}%")
