# %% [markdown]
# # CNN attack using Skywater non-linearized data
#
# The goal of this notebook is to correctly preprocess the given data as tensors, train and test a CNN model.

# %%
# dataloader.py
# Necessary imports
from torch.utils.data import Dataset, DataLoader
import numpy as np
import os
import re

# %% [markdown]
# ## Creating dataloaders
# Used files from Kareem's GitHub repo. I may have made mistakes in sampling the data, so feel free to change anything that has been configured incorrectly.

# %% [markdown]
# ### Helper functions - Dataloaders

# %%
# dataloader.py
# Returns list of files with given format 
def get_files(directory, format, digital_index=0):

    format = re.compile(format)
    files = os.listdir(directory)

    #file_dict = {}
    file_list = [] # fname, fpath, label

    for fname in files:
        if match := format.match(fname):
            fpath = os.path.join(directory, fname)

            dvalue = int(match.groups()[digital_index])
            
            file_list.append((fname, fpath, dvalue))

            #if dvalue in file_dict:
            #    file_dict[dvalue].append(fpath)
            #else:
            #    file_dict[dvalue] = [fpath]

    return file_list #file_dict, file_path

# Creates dataset with given traces
class TraceDataset(Dataset):
    cached_traces = {}
    trace_list    = []

    def __init__(self, file_list, cache=True):
        self.file_list = file_list
        self.cache     = cache

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, index):
        fname, fpath, label = self.file_list[index]
        label = self.process_label(label)

        if self.cache and fname in self.cached_traces:
            return self.cached_traces[fname], label
        else:
            return self.load_trace(fname, fpath), label

    def get_info(self, index):
        return self.file_list[index]

    def load_trace(self, fname, fpath):
        with open(fpath, 'r') as file:
            header = file.readline()
            #time_arr = []
            valu_arr = []

            for line in file.readlines():
                time, value = line.strip().split()
                #time_arr.append(np.float32(time))
                valu_arr.append(np.float32(value))

        trace = np.array(valu_arr, dtype=np.float32)

        if self.cache: 
            self.cached_traces[fname] = trace
            self.trace_list.append(trace)

        return trace
    
    def process_label(self, label): return label

    def cache_all(self):
        assert self.cache == True

        print("Caching all traces")
        for fname, fpath, label in self.file_list:
            self.load_trace(fname, fpath)
        print("DONE Caching all traces")

class TraceDatasetBW(TraceDataset):
    def __init__(self, file_list, bit_select, cache=True):
        self.bit_mask = 1 << bit_select
        super().__init__(file_list, cache=cache)

    def process_label(self, label):
        return 1 if label & self.bit_mask else 0

class TraceDatasetBuilder:
    def __init__(self, adc_bitwidth=8, cache=True):
        self.file_list        = []
        self.cache = cache
        self.adc_bits = adc_bitwidth

        self.dataset = None
        self.dataloader = None
        self.datasets = []
        self.dataloaders = []

    def add_files(self, directory, format, label_group):
        ''' Builds list of powertrace files
        Inputs:
            directory   : folder to search for files
            format      : regular expression to match filenames
            label_index : group index for digital output label corresponding to trace
        Outputs:
            list        : [(file_name, file_path, label) ... ]
        '''
        format = re.compile(format)
        fnames = os.listdir(directory)

        for fname in fnames:
            if match := format.match(fname):
                fpath = os.path.join(directory, fname)
                dvalue = int(match.groups()[label_group])

                self.file_list.append((fname, fpath, dvalue))

    def build(self):
        self.dataset = TraceDataset(self.file_list, cache=self.cache)
        for b in range(self.adc_bits):
            self.datasets.append(TraceDatasetBW(self.file_list, b, cache=self.cache))

        if self.cache:
            self.dataset.cache_all()

    def build_dataloaders(self, **kwargs): # batch_size=256, shuffle=True
        self.dataloader = DataLoader(self.dataset, **kwargs)
        self.dataloaders = [DataLoader(dataset, **kwargs) for dataset in self.datasets]

# %% [markdown]
# ## Creating dataloaders
# This section:
# 1) Creates dataloaders for both the training and testing datasets.
# 2) Validates and checks the contents of each dataset.
# 3) Common variables, such as "input_size" are instantiated.

# %%
# Hyperparameters for dataloaders
adc_bits = 8

# %%
# Create dataloaders
pwd = os.getcwd()
# print(pwd)
# proj_dir = os.path.dirname(os.path.dirname(pwd))
# print(proj_dir)
# data_dir = os.path.join(pwd, 'analog', 'outfiles')

builder  = TraceDatasetBuilder(adc_bitwidth=adc_bits, cache=True)
builder.add_files(os.path.join(pwd, 'sky_Dec_18_2151'), "sky_d(\\d+)_.*\\.txt", 0)
builder.build()
builder.build_dataloaders(batch_size=256, shuffle=True)

# Initialize dataloaders
dataloaders = builder.dataloaders

try:
    print(f"\nTotal number of datasets in dataloaders: {len(dataloaders)}")
except ModuleNotFoundError:
    print("\tERROR: Dataloader not found. Recheck your implementation and try again.")
    raise
except Exception as e:
    print("\tERROR: Dataloader invalid. Recheck your implementation and try again.")
    raise

if not dataloaders or len(dataloaders) != adc_bits:
    print(f"\tERROR: Dataloader size is incorrect: {len(dataloaders) if dataloaders else 0}. It should be: {adc_bits}.")
    print("\tRecheck your implementation and try again.")
    raise ValueError("Invalid dataloader size")

# Extract input_size and validate initial dataloader
input_size, label_num = None, None
for input, labels in dataloaders[0]:
    print(input.size())
    input_size = input.size(1)
    label_num = len(labels)
    print(f"Input size: {input_size}")
    print(f"Number of labels: {label_num}\n")

    if input.size(0) != label_num:
        print("\tERROR: Number of traces per input is different from number of labels.")
        print(f"\tNumber of traces per input: {input.size(0)}")
        print(f"\tNumber of labels: {label_num}\n")
        raise ValueError("Mismatch between input size and number of labels")

# Validate all dataloaders
for idx, dataloader in enumerate(dataloaders):
    for input, labels in dataloader:
        if input.size(0) != label_num:
            print(f"\tERROR: Number of traces per input is incorrect in dataloader {idx}.")
            print(f"\tExpected: {label_num}, but got: {input.size(0)}.")
            raise ValueError("Invalid number of traces per input")

        if input.size(1) != input_size:
            print(f"\tERROR: Size of traces per input is incorrect in dataloader {idx}.")
            print(f"\tExpected: {input_size}, but got: {input.size(1)}.")
            raise ValueError("Invalid trace size")

        if len(labels) != label_num:
            print(f"\tERROR: Number of labels is incorrect in dataloader {idx}.")
            print(f"\tExpected: {label_num}, but got: {len(labels)}.")
            raise ValueError("Invalid label count")

    print(f"Validation for dataloader {idx} complete.")

print("\nAll dataloaders are valid. Proceeding to training...")
# Out:
# Caching all traces
# DONE Caching all traces
#
# Total number of datasets in dataloaders: 8
# torch.Size([256, 3001])
# Input size: 3001
# Number of labels: 256
#
# Validation for dataloader 0 complete.
# Validation for dataloader 1 complete.
# Validation for dataloader 2 complete.
# Validation for dataloader 3 complete.
# Validation for dataloader 4 complete.
# Validation for dataloader 5 complete.
# Validation for dataloader 6 complete.
# Validation for dataloader 7 complete.
#
# All dataloaders are valid. Proceeding to training...

# %% [markdown]
# ### Setup for CNN
# Section where the initial imports and variables for our native CNN.

# %%
# CNN code
# Necessary imports
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
import numpy as np
import datetime

# %% [markdown]
# ### Optimizing CUDA version
# Section where we desginate the most updated CUDA version for current GPU.
#
# Implementation in progress, but is a lot of unnecessary work; will do if CPU training speeds are unformidable.

# %% [markdown]
# ## Training CNNs - Native CNN
# Using a native CNN, we train each CNN until all of them reaches an accuracy of 1.0.
#
# I'm not sure if aiming for an accuracy of 1.0 is beneficial, as it is just overfitting the model to the training data. A more realistic value may be 0.99, but will set it to 1.0 for the current simulated environment.
#
# The training function automatically reduces the learning rate used in Adam based on target accuracy. Currently testing different values and decrease rates.

# %% [markdown]
# ### Hyperparameters
#
# 1) def_lr: Default learning rate. Change this value to test different learning rate values.
# 2) divide_lr: Rate of how much the learning rate should be reduced if weight decay is enabled. Increase this value to decrease the learning rate more.
# 3) enable_weight_decay: If set to 'True', enables (1) updating the learning rate according to the resulting accuracy values and (2) oscillation detection (updating the learning rate if there are no improvements over multiple training epochs).
# 4) freeze_layers: If set to 'True', freezes all layers of ResNet with no additional training to those layers.

# %%
# Main hyperparameters
def_lr = 1e-3
divide_lr = 2
enable_weight_decay = False
freeze_layers = False

# %% [markdown]
# ### CNN model initialization
# Function that initializes the CNN architecture.
#
# The architecture of the original CNN from the S2ADC paper is as follows:
#
# C = Convolution layer, [filter_num, kernel_size, stride]
#
# MP = Max Pool layer, [pool_zie, stride]
#
# FC = Fully Connected layer, [neuron_num]
#
# OUT = Output layer(another FC), [neuron_num]
#
# C1[5,5,1]
#
# MP1[5,5]
#
# C2[5,5,1]
#
# MP2[5,5]
#
# FC1[100]
#
# FC2[100]
#
# FC3[100]
#
# OUT[2]
#
# This architecture would most likely be needed to be tweaked for our usecase as our ADC is significiantly more complex.

# %%
# Class that defines our CNN model
class psa_CNN(nn.Module):
    def __init__(self):
        super(psa_CNN, self).__init__()
        # 1-D convolution layers
        # Activation = ReLU
        # 5 filters, kernel size = 5, stride = 1, zero padding
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=5, kernel_size=5, stride=1)
        self.conv2 = nn.Conv1d(in_channels=5, out_channels=5, kernel_size=5, stride=1)
        self.conv3 = nn.Conv1d(in_channels=5, out_channels=5, kernel_size=5, stride=1)
        self.conv4 = nn.Conv1d(in_channels=5, out_channels=5, kernel_size=5, stride=1)
        # Pooling layers
        # MaxPool, pooling size = 5, stride = 5
        # input = [label_num, input_size - 8, 1]
        # output = [(label_num - 5)/5 + 1, (input_size - 8 - 5)/5 + 1, 1]
        # = [(label_num - 5)/5 + 1, (input_size - 13)/5 + 1, 1]
        self.pool1 = nn.MaxPool1d(kernel_size=5, stride=5)
        self.pool2 = nn.MaxPool1d(kernel_size=5, stride=5)
        self.pool3 = nn.MaxPool1d(kernel_size=5, stride=5)
        self.pool4 = nn.MaxPool1d(kernel_size=5, stride=5)
        # Fully connected layers
        # Activation = ReLU
        # 100 neurons
        self.fc1 = nn.Linear(595, 100)
        self.fc2 = nn.Linear(100, 100)
        self.fc3 = nn.Linear(100, 100)
        self.fc4 = nn.Linear(100, 100)
        self.fc5 = nn.Linear(100, 100)
        self.fc6 = nn.Linear(100, 100)
        self.fc7 = nn.Linear(100, 100)
        self.fc8 = nn.Linear(100, 100)
        # Output layer
        # 2 neurons, softmax
        self.o1 = nn.Linear(100, 2)

    def forward(self, x):
        x = x.unsqueeze(1)
        # First convolutional layer
        x = torch.relu(self.conv1(x))
        x = self.pool1(x)
        x = torch.relu(self.conv2(x))
        x = self.pool2(x)
        '''
        x = torch.relu(self.conv3(x))
        x = self.pool3(x)
        x = torch.relu(self.conv4(x))
        x = self.pool4(x)
        '''
        # Flatten the output
        x = x.view(x.size(0), -1)
        # Fully connected layers
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = torch.relu(self.fc5(x))
        x = torch.relu(self.fc6(x))
        x = torch.relu(self.fc7(x))
        x = torch.relu(self.fc8(x))
        # Output layer, softmax
        x = torch.softmax(self.o1(x), dim=1)
        return x

# %% [markdown]
# ### Helper Functions

# %%
''' 
Function that initializes the CNN and its core components.
Inputs:
    None
Returns:
    1) cnn: model used(ResNet18)
    2) criterion: loss function, current default=CrossEntropyLoss
    3) learning_rate: learning rate, current default=def_lr
    4) optimizer: optimizer, current default=Adam
'''
def cnn_init():
    # Model: custom CNN, inspired by the S2ADC paper
    cnn = psa_CNN()
    # Loss function: not specified in paper, using Cross Entropy Loss
    criterion = nn.CrossEntropyLoss()

    # Learning rate: default set to def_lr, adjust accordingly
    # Optimizer: not specified in paper, using Adam
    learning_rate = def_lr
    optimizer = optim.Adam(cnn.parameters(), lr=learning_rate)
    return cnn, criterion, learning_rate, optimizer

''' 
Function that initializes parameters used in training.
Inputs:
    None
Returns:
    TARGET ACCURACY PARAMETERS
    1) target_acc: array with target accuracies which reached updates the learning rate
    2) target_acc_index: value used to track progress of target accuracy
    OSCILLATION CHECKING PARAMETERS
    3) is_osc: boolean value that is set to true when oscillation is detected. Automatically set to False
    if new .pth file is loaded.
    4) osc_count: value that counts number of similar accuracy outputs to check oscillation
    TRAINING PARAMETERS
    5) num_epochs: number of maximum epochs per training
    6) max_grad_norm: gradient clipping threshold
    WEIGHT DECAY PARAMETER
    7) weight_decay: set to hyperparameter value 'enable_weight_decay'.
    If True, enables weight decay and oscallation update. If False, disables it.
'''
def param_init():
    # target accuracy parameters
    target_acc = [0.90, 0.95, 0.99, 0.995, 1.0]
    target_acc_index = 0
    
    # oscillation checking parameters
    is_osc = False
    osc_count = 0

    # training parameters
    num_epochs = 100000
    max_grad_norm = 1.0

    # weight decay parameter
    weight_decay = enable_weight_decay
    
    return target_acc, target_acc_index, is_osc, osc_count, num_epochs, max_grad_norm, weight_decay

''' 
Function that loads variables from saved .pth file. Checks if the file is valid.
This function simply receives the checkpoint file and checks if it is valid.
Inputs:
    1) checkpoint_path: string of .pth file name 
    2) device: selected device to run training
Returns:
    1) pth_variables: dictionary that contains received .pth variables.
    List of variables are saved in 'load_values' array.
'''
def load_pth_file(checkpoint_path, device, load_values):
    pth_variables = {}
    # Load .pth file
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=True)
        for values in load_values:
            pth_variables[values] = checkpoint.get(values, 0)
        return pth_variables
    except FileNotFoundError:
        print(f"No checkpoint found at {checkpoint_path}. Starting from scratch.")
        raise
    except KeyError as e:
        missing_keys = {
            'cnn_state_dict': "CNN state dictionary",
            'optimizer_state_dict': "optimizer state dictionary",
            'epoch': "epoch",
            'reached_acc': "recorded accuracy of current epoch",
            'osc_count': "oscillation count"
        }
        key = e.args[0]
        if key in missing_keys:
            if key in ['cnn_state_dict', 'optimizer_state_dict', 'epoch', 'reached_acc']:
                print(f"Critical error: Missing \"{key}\" that stores \"{missing_keys[key]}\". Checkpoint file is invalid.")
                raise
            else:
                print(f"Warning: Missing \"{key}\" that stores \"{missing_keys[key]}\". Default values will be used.")
                if key == 'osc_count':
                    osc_count = 0

        print(f"Unknown parameter \"{key}\" in checkpoint. Recheck file and try again.")
        raise

''' 
Function that updates learning rate accordingly from current reached target accuracy.
This function allows changing values in the target_acc array without additional components.
Inputs:
    1) target_acc: array with target accuracies which reached updates the learning rate
    2) target_acc_index: index value of previous target accuracy value
    3) learning_rate: learning rate from CNN
    4) reached_acc: previously reached accuracy
    5) force_update: boolean that specifies if the function is called intentionally.
    If set to True, print results
Returns:
    1) learning_rate: new updated learning rate
    2) target_acc_index: updated index value of new target accuracy value
'''
def update_learning_rate(target_acc, target_acc_index, learning_rate, reached_acc, force_update):
    temp = learning_rate
    updated = False
    while target_acc_index < len(target_acc) - 1 and target_acc[target_acc_index] < reached_acc:
        updated = True
        target_acc_index += 1
        learning_rate /= divide_lr * (target_acc_index)
    if force_update:
        print(f"\tUpdated target accuracy: {target_acc[target_acc_index]}")
        print(f"\tUpdated learning rate: {learning_rate}")
    elif updated:
        print(f"Reached target accuracy {target_acc[target_acc_index-1]}")
        print(f"New target accuracy {target_acc[target_acc_index]}")
        print(f"Updating learning rate FROM: {temp}, TO: {learning_rate}")
    return learning_rate, target_acc_index

# %%
cnns = []
dataloaders = builder.dataloaders 
timestamp   = datetime.datetime.now().strftime('%Y%m%d_%H%M')

print(f"Installed CUDA version: {torch.version.cuda}\n")

# Create CNN per dataset
for i in range(7,-1,-1):
    print(f"Starting training for \"cnn_{i}\"...")

    # initialize CNN
    cnn, criterion, learning_rate, optimizer = cnn_init()
    # Save default learning rate
    default_lr = learning_rate
    # initialize parameters
    target_acc, target_acc_index, is_osc, osc_count, num_epochs, max_grad_norm, weight_decay = param_init()

    if weight_decay:
        print("\tWeight decay enabled. Learning rate update and oscillation detection enabled.")
    else:
        print("\tWeight decay disabled. Learning rate update and oscillation detection disabled.")

    # Append CNN to cnns array
    cnns.append(cnn)

    # Create checkpoint to save progress
    checkpoint_path = f"cnn_checkpoint_{i}.pth"
    
    # Set device to cuda if available
    if torch.cuda.is_available():
        print("\tGPU found, running training on GPU...")
        device = torch.device("cuda")
        cnn = cnn.to(device)
    else:
        print("\tNo GPU found, running training on CPU...")
        print("\tRecheck CUDA version and if your GPU supports it.")
        device = torch.device("cpu")

    # Attempt to load saved .pth file
    # start_epoch = LOCAL variable that specifies starting epoch number
    # prev_acc = LOCAL variable that specifies accuracy achieved by loaded .pth file
    # osc_count = variable used to check oscillation, same name as dictionary key in .pth file
    load_values = ['cnn_state_dict', 'optimizer_state_dict', 'epoch', 'reached_acc', 'osc_count']
    try:
        pth_vars = load_pth_file(checkpoint_path, device, load_values)
    except FileNotFoundError:
        start_epoch = 0
        prev_acc = 0
        osc_count = 0
    else:
        # Manually create variables per value
        cnn.load_state_dict(pth_vars['cnn_state_dict'])
        optimizer.load_state_dict(pth_vars['optimizer_state_dict'])
        start_epoch = pth_vars['epoch']
        prev_acc = pth_vars['reached_acc']
        osc_count = pth_vars['osc_count']
    
        print(f"Checkpoint loaded. Resuming from epoch {start_epoch}.")
        print(f"\tPrevious reached accuracy: {prev_acc}.")

    # Skip training if target accuracy is reached
    if prev_acc == 1:
        print(f"\tSkipping training: accuracy of 1 already achieved.\n")
        continue
    
    if weight_decay:
        # Adjust learning rate
        learning_rate, target_acc_index = update_learning_rate(target_acc, target_acc_index, learning_rate, prev_acc, force_update=True)
        optimizer = optim.Adam(cnn.parameters(), lr=learning_rate)

    # Start training
    for e in range(start_epoch, num_epochs):
        correct = 0
        cnn.train()

        for inputs, labels in dataloaders[i]:
            inputs, labels = inputs.to(device), labels.to(device)
            # Add dimensions for channels and width
            # inputs = inputs.unsqueeze(1).unsqueeze(-1)
            optimizer.zero_grad()
            output = cnn(inputs)
            # Check for NaN in outputs
            if torch.isnan(output).any():
                print("NaN detected in cnn outputs.")
                break

            loss = criterion(output, labels)
            # Check for NaN in loss
            if torch.isnan(loss):
                print("NaN detected in loss. Stopping training.")
                break
            # print(f"Loss: {loss.item()}")
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cnn.parameters(), max_grad_norm)
            optimizer.step()
            _, predicted = torch.max(output, 1)
            correct += (predicted == labels).sum()
        
        accuracy = correct / 256

        # Change rate of update for printing accuracy accordingly
        if (e + 1) % 1 == 0:
            print(f'TRAINING: cnn[{i}], Epoch {e+1}, Loss: {loss.item()}')
            print(f'TRAINING: cnn[{i}], Epoch {e+1}, Accuracy: {accuracy}')

        if weight_decay:
            # Check oscillation and update learning rate
            # 1) is_osc == False: not in reset phase
            # 1-a) check difference between accuracy and prev_acc, update osc_count
            # 1-b) IF updated osc_count > 7, means oscillating, set learning rate to default value
            # 1-c) ELSE not oscillating, check if target learning rate is reached
            # 2) is_osc == True: in reset phase
            # 2-a) check if osc_count == 0
            # 2-b) IF osc_count == 0, reset phase is complete, re-update learning rate
            if not is_osc:
                if abs(accuracy - prev_acc) < 0.001:
                    osc_count += 1
                else:
                    osc_count = 0
                if osc_count > 7:
                    print(f"\tOSCILLATION DETECTED. Resetting learning rate to {default_lr}...")
                    is_osc = True
                    learning_rate = default_lr
                    osc_count = 3
                else:
                    # Adjust learning rate
                    learning_rate, target_acc_index = update_learning_rate(target_acc, target_acc_index, learning_rate, accuracy, force_update=False)
                    optimizer = optim.Adam(cnn.parameters(), lr=learning_rate)
            else:
                if osc_count == 0:
                    # Adjust learning rate
                    print("\tLearning rate reset completed, adjusting learning rate...")
                    learning_rate, target_acc_index = update_learning_rate(target_acc, 0, learning_rate, accuracy, force_update=True)
                    optimizer = optim.Adam(cnn.parameters(), lr=learning_rate)
                    is_osc = False
                else:
                    osc_count -= 1

        # Save checkpoint
        torch.save({
            'cnn_state_dict': cnn.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epoch': e + 1,
            'reached_acc': accuracy,
            'osc_count': osc_count
        }, checkpoint_path)
        print(f"Checkpoint saved for epoch {e + 1}")

        prev_acc = accuracy

        if accuracy == 1:
            print(f"Reached accuracy of 1. Stopping training for \"cnn_{i}\".\n")
            break
# Out:
# Installed CUDA version: None
#
# Starting training for "cnn_7"...
# 	Weight decay disabled. Learning rate update and oscillation detection disabled.
# 	No GPU found, running training on CPU...
# 	Recheck CUDA version and if your GPU supports it.
# No checkpoint found at cnn_checkpoint_7.pth. Starting from scratch.
# TRAINING: cnn[7], Epoch 1, Loss: 0.6944003105163574
# TRAINING: cnn[7], Epoch 1, Accuracy: 0.5
# Checkpoint saved for epoch 1
# TRAINING: cnn[7], Epoch 2, Loss: 0.6940954327583313
# TRAINING: cnn[7], Epoch 2, Accuracy: 0.5
# Checkpoint saved for epoch 2
# TRAINING: cnn[7], Epoch 3, Loss: 0.6938422918319702
# TRAINING: cnn[7], Epoch 3, Accuracy: 0.5
# Checkpoint saved for epoch 3
# TRAINING: cnn[7], Epoch 4, Loss: 0.6936389207839966
# TRAINING: cnn[7], Epoch 4, Accuracy: 0.5
# Checkpoint saved for epoch 4
# TRAINING: cnn[7], Epoch 5, Loss: 0.6934676766395569
# TRAINING: cnn[7], Epoch 5, Accuracy: 0.5
# Checkpoint saved for epoch 5
# TRAINING: cnn[7], Epoch 6, Loss: 0.6933289766311646
# TRAINING: cnn[7], Epoch 6, Accuracy: 0.5
# Checkpoint saved for epoch 6
# TRAINING: cnn[7], Epoch 7, Loss: 0.6932256817817688
# TRAINING: cnn[7], Epoch 7, Accuracy: 0.5
# Checkpoint saved for epoch 7
# TRAINING: cnn[7], Epoch 8, Loss: 0.6931622624397278
# TRAINING: cnn[7], Epoch 8, Accuracy: 0.5
# Checkpoint saved for epoch 8
# TRAINING: cnn[7], Epoch 9, Loss: 0.693148672580719
# TRAINING: cnn[7], Epoch 9, Accuracy: 0.5
# Checkpoint saved for epoch 9
# TRAINING: cnn[7], Epoch 10, Loss: 0.6931814551353455
# TRAINING: cnn[7], Epoch 10, Accuracy: 0.5
# Checkpoint saved for epoch 10
# TRAINING: cnn[7], Epoch 11, Loss: 0.6932249069213867
# TRAINING: cnn[7], Epoch 11, Accuracy: 0.5
# Checkpoint saved for epoch 11
# TRAINING: cnn[7], Epoch 12, Loss: 0.6932446360588074
# TRAINING: cnn[7], Epoch 12, Accuracy: 0.5
# Checkpoint saved for epoch 12
# TRAINING: cnn[7], Epoch 13, Loss: 0.6932421922683716
# TRAINING: cnn[7], Epoch 13, Accuracy: 0.5
# Checkpoint saved for epoch 13
# TRAINING: cnn[7], Epoch 14, Loss: 0.6932245492935181
# TRAINING: cnn[7], Epoch 14, Accuracy: 0.5
# Checkpoint saved for epoch 14
# TRAINING: cnn[7], Epoch 15, Loss: 0.6932019591331482
# TRAINING: cnn[7], Epoch 15, Accuracy: 0.5
# Checkpoint saved for epoch 15
# TRAINING: cnn[7], Epoch 16, Loss: 0.6931807994842529
# TRAINING: cnn[7], Epoch 16, Accuracy: 0.5
# Checkpoint saved for epoch 16
# TRAINING: cnn[7], Epoch 17, Loss: 0.6931641101837158
# TRAINING: cnn[7], Epoch 17, Accuracy: 0.5
# Checkpoint saved for epoch 17
# TRAINING: cnn[7], Epoch 18, Loss: 0.6931535005569458
# TRAINING: cnn[7], Epoch 18, Accuracy: 0.5
# Checkpoint saved for epoch 18
# TRAINING: cnn[7], Epoch 19, Loss: 0.6931481957435608
# TRAINING: cnn[7], Epoch 19, Accuracy: 0.5
# Checkpoint saved for epoch 19
# TRAINING: cnn[7], Epoch 20, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 20, Accuracy: 0.5
# Checkpoint saved for epoch 20
# TRAINING: cnn[7], Epoch 21, Loss: 0.6931493282318115
# TRAINING: cnn[7], Epoch 21, Accuracy: 0.5
# Checkpoint saved for epoch 21
# TRAINING: cnn[7], Epoch 22, Loss: 0.6931527853012085
# TRAINING: cnn[7], Epoch 22, Accuracy: 0.5
# Checkpoint saved for epoch 22
# TRAINING: cnn[7], Epoch 23, Loss: 0.6931561827659607
# TRAINING: cnn[7], Epoch 23, Accuracy: 0.5
# Checkpoint saved for epoch 23
# TRAINING: cnn[7], Epoch 24, Loss: 0.6931591629981995
# TRAINING: cnn[7], Epoch 24, Accuracy: 0.5
# Checkpoint saved for epoch 24
# TRAINING: cnn[7], Epoch 25, Loss: 0.6931608319282532
# TRAINING: cnn[7], Epoch 25, Accuracy: 0.5
# Checkpoint saved for epoch 25
# TRAINING: cnn[7], Epoch 26, Loss: 0.693161129951477
# TRAINING: cnn[7], Epoch 26, Accuracy: 0.5
# Checkpoint saved for epoch 26
# TRAINING: cnn[7], Epoch 27, Loss: 0.6931600570678711
# TRAINING: cnn[7], Epoch 27, Accuracy: 0.5
# Checkpoint saved for epoch 27
# TRAINING: cnn[7], Epoch 28, Loss: 0.6931582689285278
# TRAINING: cnn[7], Epoch 28, Accuracy: 0.5
# Checkpoint saved for epoch 28
# TRAINING: cnn[7], Epoch 29, Loss: 0.6931557655334473
# TRAINING: cnn[7], Epoch 29, Accuracy: 0.5
# Checkpoint saved for epoch 29
# TRAINING: cnn[7], Epoch 30, Loss: 0.6931532025337219
# TRAINING: cnn[7], Epoch 30, Accuracy: 0.5
# Checkpoint saved for epoch 30
# TRAINING: cnn[7], Epoch 31, Loss: 0.6931507587432861
# TRAINING: cnn[7], Epoch 31, Accuracy: 0.5
# Checkpoint saved for epoch 31
# TRAINING: cnn[7], Epoch 32, Loss: 0.6931490898132324
# TRAINING: cnn[7], Epoch 32, Accuracy: 0.5
# Checkpoint saved for epoch 32
# TRAINING: cnn[7], Epoch 33, Loss: 0.6931476593017578
# TRAINING: cnn[7], Epoch 33, Accuracy: 0.5
# Checkpoint saved for epoch 33
# TRAINING: cnn[7], Epoch 34, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 34, Accuracy: 0.5
# Checkpoint saved for epoch 34
# TRAINING: cnn[7], Epoch 35, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 35, Accuracy: 0.5
# Checkpoint saved for epoch 35
# TRAINING: cnn[7], Epoch 36, Loss: 0.6931478977203369
# TRAINING: cnn[7], Epoch 36, Accuracy: 0.5
# Checkpoint saved for epoch 36
# TRAINING: cnn[7], Epoch 37, Loss: 0.6931488513946533
# TRAINING: cnn[7], Epoch 37, Accuracy: 0.5
# Checkpoint saved for epoch 37
# TRAINING: cnn[7], Epoch 38, Loss: 0.6931496262550354
# TRAINING: cnn[7], Epoch 38, Accuracy: 0.5
# Checkpoint saved for epoch 38
# TRAINING: cnn[7], Epoch 39, Loss: 0.6931499242782593
# TRAINING: cnn[7], Epoch 39, Accuracy: 0.5
# Checkpoint saved for epoch 39
# TRAINING: cnn[7], Epoch 40, Loss: 0.6931503415107727
# TRAINING: cnn[7], Epoch 40, Accuracy: 0.5
# Checkpoint saved for epoch 40
# TRAINING: cnn[7], Epoch 41, Loss: 0.6931500434875488
# TRAINING: cnn[7], Epoch 41, Accuracy: 0.5
# Checkpoint saved for epoch 41
# TRAINING: cnn[7], Epoch 42, Loss: 0.6931495070457458
# TRAINING: cnn[7], Epoch 42, Accuracy: 0.5
# Checkpoint saved for epoch 42
# TRAINING: cnn[7], Epoch 43, Loss: 0.6931487917900085
# TRAINING: cnn[7], Epoch 43, Accuracy: 0.5
# Checkpoint saved for epoch 43
# TRAINING: cnn[7], Epoch 44, Loss: 0.6931481957435608
# TRAINING: cnn[7], Epoch 44, Accuracy: 0.5
# Checkpoint saved for epoch 44
# TRAINING: cnn[7], Epoch 45, Loss: 0.6931477189064026
# TRAINING: cnn[7], Epoch 45, Accuracy: 0.5
# Checkpoint saved for epoch 45
# TRAINING: cnn[7], Epoch 46, Loss: 0.6931474208831787
# TRAINING: cnn[7], Epoch 46, Accuracy: 0.5
# Checkpoint saved for epoch 46
# TRAINING: cnn[7], Epoch 47, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 47, Accuracy: 0.5
# Checkpoint saved for epoch 47
# TRAINING: cnn[7], Epoch 48, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 48, Accuracy: 0.5
# Checkpoint saved for epoch 48
# TRAINING: cnn[7], Epoch 49, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 49, Accuracy: 0.5
# Checkpoint saved for epoch 49
# TRAINING: cnn[7], Epoch 50, Loss: 0.6931475400924683
# TRAINING: cnn[7], Epoch 50, Accuracy: 0.5
# Checkpoint saved for epoch 50
# TRAINING: cnn[7], Epoch 51, Loss: 0.6931478977203369
# TRAINING: cnn[7], Epoch 51, Accuracy: 0.5
# Checkpoint saved for epoch 51
# TRAINING: cnn[7], Epoch 52, Loss: 0.6931477189064026
# TRAINING: cnn[7], Epoch 52, Accuracy: 0.5
# Checkpoint saved for epoch 52
# TRAINING: cnn[7], Epoch 53, Loss: 0.6931478977203369
# TRAINING: cnn[7], Epoch 53, Accuracy: 0.5
# Checkpoint saved for epoch 53
# TRAINING: cnn[7], Epoch 54, Loss: 0.6931479573249817
# TRAINING: cnn[7], Epoch 54, Accuracy: 0.5
# Checkpoint saved for epoch 54
# TRAINING: cnn[7], Epoch 55, Loss: 0.6931478977203369
# TRAINING: cnn[7], Epoch 55, Accuracy: 0.5
# Checkpoint saved for epoch 55
# TRAINING: cnn[7], Epoch 56, Loss: 0.693147599697113
# TRAINING: cnn[7], Epoch 56, Accuracy: 0.5
# Checkpoint saved for epoch 56
# TRAINING: cnn[7], Epoch 57, Loss: 0.6931475400924683
# TRAINING: cnn[7], Epoch 57, Accuracy: 0.5
# Checkpoint saved for epoch 57
# TRAINING: cnn[7], Epoch 58, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 58, Accuracy: 0.5
# Checkpoint saved for epoch 58
# TRAINING: cnn[7], Epoch 59, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 59, Accuracy: 0.5
# Checkpoint saved for epoch 59
# TRAINING: cnn[7], Epoch 60, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 60, Accuracy: 0.5
# Checkpoint saved for epoch 60
# TRAINING: cnn[7], Epoch 61, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 61, Accuracy: 0.5
# Checkpoint saved for epoch 61
# TRAINING: cnn[7], Epoch 62, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 62, Accuracy: 0.5
# Checkpoint saved for epoch 62
# TRAINING: cnn[7], Epoch 63, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 63, Accuracy: 0.5
# Checkpoint saved for epoch 63
# TRAINING: cnn[7], Epoch 64, Loss: 0.6931475400924683
# TRAINING: cnn[7], Epoch 64, Accuracy: 0.5
# Checkpoint saved for epoch 64
# TRAINING: cnn[7], Epoch 65, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 65, Accuracy: 0.5
# Checkpoint saved for epoch 65
# TRAINING: cnn[7], Epoch 66, Loss: 0.6931474208831787
# TRAINING: cnn[7], Epoch 66, Accuracy: 0.5
# Checkpoint saved for epoch 66
# TRAINING: cnn[7], Epoch 67, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 67, Accuracy: 0.5
# Checkpoint saved for epoch 67
# TRAINING: cnn[7], Epoch 68, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 68, Accuracy: 0.5
# Checkpoint saved for epoch 68
# TRAINING: cnn[7], Epoch 69, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 69, Accuracy: 0.5
# Checkpoint saved for epoch 69
# TRAINING: cnn[7], Epoch 70, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 70, Accuracy: 0.5
# Checkpoint saved for epoch 70
# TRAINING: cnn[7], Epoch 71, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 71, Accuracy: 0.5
# Checkpoint saved for epoch 71
# TRAINING: cnn[7], Epoch 72, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 72, Accuracy: 0.5
# Checkpoint saved for epoch 72
# TRAINING: cnn[7], Epoch 73, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 73, Accuracy: 0.5
# Checkpoint saved for epoch 73
# TRAINING: cnn[7], Epoch 74, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 74, Accuracy: 0.5
# Checkpoint saved for epoch 74
# TRAINING: cnn[7], Epoch 75, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 75, Accuracy: 0.5
# Checkpoint saved for epoch 75
# TRAINING: cnn[7], Epoch 76, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 76, Accuracy: 0.5
# Checkpoint saved for epoch 76
# TRAINING: cnn[7], Epoch 77, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 77, Accuracy: 0.5
# Checkpoint saved for epoch 77
# TRAINING: cnn[7], Epoch 78, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 78, Accuracy: 0.5
# Checkpoint saved for epoch 78
# TRAINING: cnn[7], Epoch 79, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 79, Accuracy: 0.5
# Checkpoint saved for epoch 79
# TRAINING: cnn[7], Epoch 80, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 80, Accuracy: 0.5
# Checkpoint saved for epoch 80
# TRAINING: cnn[7], Epoch 81, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 81, Accuracy: 0.5
# Checkpoint saved for epoch 81
# TRAINING: cnn[7], Epoch 82, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 82, Accuracy: 0.5
# Checkpoint saved for epoch 82
# TRAINING: cnn[7], Epoch 83, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 83, Accuracy: 0.5
# Checkpoint saved for epoch 83
# TRAINING: cnn[7], Epoch 84, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 84, Accuracy: 0.5
# Checkpoint saved for epoch 84
# TRAINING: cnn[7], Epoch 85, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 85, Accuracy: 0.5
# Checkpoint saved for epoch 85
# TRAINING: cnn[7], Epoch 86, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 86, Accuracy: 0.5
# Checkpoint saved for epoch 86
# TRAINING: cnn[7], Epoch 87, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 87, Accuracy: 0.5
# Checkpoint saved for epoch 87
# TRAINING: cnn[7], Epoch 88, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 88, Accuracy: 0.5
# Checkpoint saved for epoch 88
# TRAINING: cnn[7], Epoch 89, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 89, Accuracy: 0.5
# Checkpoint saved for epoch 89
# TRAINING: cnn[7], Epoch 90, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 90, Accuracy: 0.5
# Checkpoint saved for epoch 90
# TRAINING: cnn[7], Epoch 91, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 91, Accuracy: 0.5
# Checkpoint saved for epoch 91
# TRAINING: cnn[7], Epoch 92, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 92, Accuracy: 0.5
# Checkpoint saved for epoch 92
# TRAINING: cnn[7], Epoch 93, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 93, Accuracy: 0.5
# Checkpoint saved for epoch 93
# TRAINING: cnn[7], Epoch 94, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 94, Accuracy: 0.5
# Checkpoint saved for epoch 94
# TRAINING: cnn[7], Epoch 95, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 95, Accuracy: 0.5
# Checkpoint saved for epoch 95
# TRAINING: cnn[7], Epoch 96, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 96, Accuracy: 0.5
# Checkpoint saved for epoch 96
# TRAINING: cnn[7], Epoch 97, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 97, Accuracy: 0.5
# Checkpoint saved for epoch 97
# TRAINING: cnn[7], Epoch 98, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 98, Accuracy: 0.5
# Checkpoint saved for epoch 98
# TRAINING: cnn[7], Epoch 99, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 99, Accuracy: 0.5
# Checkpoint saved for epoch 99
# TRAINING: cnn[7], Epoch 100, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 100, Accuracy: 0.5
# Checkpoint saved for epoch 100
# TRAINING: cnn[7], Epoch 101, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 101, Accuracy: 0.5
# Checkpoint saved for epoch 101
# TRAINING: cnn[7], Epoch 102, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 102, Accuracy: 0.5
# Checkpoint saved for epoch 102
# TRAINING: cnn[7], Epoch 103, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 103, Accuracy: 0.5
# Checkpoint saved for epoch 103
# TRAINING: cnn[7], Epoch 104, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 104, Accuracy: 0.5
# Checkpoint saved for epoch 104
# TRAINING: cnn[7], Epoch 105, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 105, Accuracy: 0.5
# Checkpoint saved for epoch 105
# TRAINING: cnn[7], Epoch 106, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 106, Accuracy: 0.5
# Checkpoint saved for epoch 106
# TRAINING: cnn[7], Epoch 107, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 107, Accuracy: 0.5
# Checkpoint saved for epoch 107
# TRAINING: cnn[7], Epoch 108, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 108, Accuracy: 0.5
# Checkpoint saved for epoch 108
# TRAINING: cnn[7], Epoch 109, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 109, Accuracy: 0.5
# Checkpoint saved for epoch 109
# TRAINING: cnn[7], Epoch 110, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 110, Accuracy: 0.5
# Checkpoint saved for epoch 110
# TRAINING: cnn[7], Epoch 111, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 111, Accuracy: 0.5
# Checkpoint saved for epoch 111
# TRAINING: cnn[7], Epoch 112, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 112, Accuracy: 0.5
# Checkpoint saved for epoch 112
# TRAINING: cnn[7], Epoch 113, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 113, Accuracy: 0.5
# Checkpoint saved for epoch 113
# TRAINING: cnn[7], Epoch 114, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 114, Accuracy: 0.5
# Checkpoint saved for epoch 114
# TRAINING: cnn[7], Epoch 115, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 115, Accuracy: 0.5
# Checkpoint saved for epoch 115
# TRAINING: cnn[7], Epoch 116, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 116, Accuracy: 0.5
# Checkpoint saved for epoch 116
# TRAINING: cnn[7], Epoch 117, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 117, Accuracy: 0.5
# Checkpoint saved for epoch 117
# TRAINING: cnn[7], Epoch 118, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 118, Accuracy: 0.5
# Checkpoint saved for epoch 118
# TRAINING: cnn[7], Epoch 119, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 119, Accuracy: 0.5
# Checkpoint saved for epoch 119
# TRAINING: cnn[7], Epoch 120, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 120, Accuracy: 0.5
# Checkpoint saved for epoch 120
# TRAINING: cnn[7], Epoch 121, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 121, Accuracy: 0.5
# Checkpoint saved for epoch 121
# TRAINING: cnn[7], Epoch 122, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 122, Accuracy: 0.5
# Checkpoint saved for epoch 122
# TRAINING: cnn[7], Epoch 123, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 123, Accuracy: 0.5
# Checkpoint saved for epoch 123
# TRAINING: cnn[7], Epoch 124, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 124, Accuracy: 0.5
# Checkpoint saved for epoch 124
# TRAINING: cnn[7], Epoch 125, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 125, Accuracy: 0.5
# Checkpoint saved for epoch 125
# TRAINING: cnn[7], Epoch 126, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 126, Accuracy: 0.5
# Checkpoint saved for epoch 126
# TRAINING: cnn[7], Epoch 127, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 127, Accuracy: 0.5
# Checkpoint saved for epoch 127
# TRAINING: cnn[7], Epoch 128, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 128, Accuracy: 0.5
# Checkpoint saved for epoch 128
# TRAINING: cnn[7], Epoch 129, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 129, Accuracy: 0.5
# Checkpoint saved for epoch 129
# TRAINING: cnn[7], Epoch 130, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 130, Accuracy: 0.5
# Checkpoint saved for epoch 130
# TRAINING: cnn[7], Epoch 131, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 131, Accuracy: 0.5
# Checkpoint saved for epoch 131
# TRAINING: cnn[7], Epoch 132, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 132, Accuracy: 0.5
# Checkpoint saved for epoch 132
# TRAINING: cnn[7], Epoch 133, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 133, Accuracy: 0.5
# Checkpoint saved for epoch 133
# TRAINING: cnn[7], Epoch 134, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 134, Accuracy: 0.5
# Checkpoint saved for epoch 134
# TRAINING: cnn[7], Epoch 135, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 135, Accuracy: 0.5
# Checkpoint saved for epoch 135
# TRAINING: cnn[7], Epoch 136, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 136, Accuracy: 0.5
# Checkpoint saved for epoch 136
# TRAINING: cnn[7], Epoch 137, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 137, Accuracy: 0.5
# Checkpoint saved for epoch 137
# TRAINING: cnn[7], Epoch 138, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 138, Accuracy: 0.5
# Checkpoint saved for epoch 138
# TRAINING: cnn[7], Epoch 139, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 139, Accuracy: 0.5
# Checkpoint saved for epoch 139
# TRAINING: cnn[7], Epoch 140, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 140, Accuracy: 0.5
# Checkpoint saved for epoch 140
# TRAINING: cnn[7], Epoch 141, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 141, Accuracy: 0.5
# Checkpoint saved for epoch 141
# TRAINING: cnn[7], Epoch 142, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 142, Accuracy: 0.5
# Checkpoint saved for epoch 142
# TRAINING: cnn[7], Epoch 143, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 143, Accuracy: 0.5
# Checkpoint saved for epoch 143
# TRAINING: cnn[7], Epoch 144, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 144, Accuracy: 0.5
# Checkpoint saved for epoch 144
# TRAINING: cnn[7], Epoch 145, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 145, Accuracy: 0.5
# Checkpoint saved for epoch 145
# TRAINING: cnn[7], Epoch 146, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 146, Accuracy: 0.5
# Checkpoint saved for epoch 146
# TRAINING: cnn[7], Epoch 147, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 147, Accuracy: 0.5
# Checkpoint saved for epoch 147
# TRAINING: cnn[7], Epoch 148, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 148, Accuracy: 0.5
# Checkpoint saved for epoch 148
# TRAINING: cnn[7], Epoch 149, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 149, Accuracy: 0.5
# Checkpoint saved for epoch 149
# TRAINING: cnn[7], Epoch 150, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 150, Accuracy: 0.5
# Checkpoint saved for epoch 150
# TRAINING: cnn[7], Epoch 151, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 151, Accuracy: 0.5
# Checkpoint saved for epoch 151
# TRAINING: cnn[7], Epoch 152, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 152, Accuracy: 0.5
# Checkpoint saved for epoch 152
# TRAINING: cnn[7], Epoch 153, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 153, Accuracy: 0.5
# Checkpoint saved for epoch 153
# TRAINING: cnn[7], Epoch 154, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 154, Accuracy: 0.5
# Checkpoint saved for epoch 154
# TRAINING: cnn[7], Epoch 155, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 155, Accuracy: 0.5
# Checkpoint saved for epoch 155
# TRAINING: cnn[7], Epoch 156, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 156, Accuracy: 0.5
# Checkpoint saved for epoch 156
# TRAINING: cnn[7], Epoch 157, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 157, Accuracy: 0.5
# Checkpoint saved for epoch 157
# TRAINING: cnn[7], Epoch 158, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 158, Accuracy: 0.5
# Checkpoint saved for epoch 158
# TRAINING: cnn[7], Epoch 159, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 159, Accuracy: 0.5
# Checkpoint saved for epoch 159
# TRAINING: cnn[7], Epoch 160, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 160, Accuracy: 0.5
# Checkpoint saved for epoch 160
# TRAINING: cnn[7], Epoch 161, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 161, Accuracy: 0.5
# Checkpoint saved for epoch 161
# TRAINING: cnn[7], Epoch 162, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 162, Accuracy: 0.5
# Checkpoint saved for epoch 162
# TRAINING: cnn[7], Epoch 163, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 163, Accuracy: 0.5
# Checkpoint saved for epoch 163
# TRAINING: cnn[7], Epoch 164, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 164, Accuracy: 0.5
# Checkpoint saved for epoch 164
# TRAINING: cnn[7], Epoch 165, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 165, Accuracy: 0.5
# Checkpoint saved for epoch 165
# TRAINING: cnn[7], Epoch 166, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 166, Accuracy: 0.5
# Checkpoint saved for epoch 166
# TRAINING: cnn[7], Epoch 167, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 167, Accuracy: 0.5
# Checkpoint saved for epoch 167
# TRAINING: cnn[7], Epoch 168, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 168, Accuracy: 0.5
# Checkpoint saved for epoch 168
# TRAINING: cnn[7], Epoch 169, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 169, Accuracy: 0.5
# Checkpoint saved for epoch 169
# TRAINING: cnn[7], Epoch 170, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 170, Accuracy: 0.5
# Checkpoint saved for epoch 170
# TRAINING: cnn[7], Epoch 171, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 171, Accuracy: 0.5
# Checkpoint saved for epoch 171
# TRAINING: cnn[7], Epoch 172, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 172, Accuracy: 0.5
# Checkpoint saved for epoch 172
# TRAINING: cnn[7], Epoch 173, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 173, Accuracy: 0.5
# Checkpoint saved for epoch 173
# TRAINING: cnn[7], Epoch 174, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 174, Accuracy: 0.5
# Checkpoint saved for epoch 174
# TRAINING: cnn[7], Epoch 175, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 175, Accuracy: 0.5
# Checkpoint saved for epoch 175
# TRAINING: cnn[7], Epoch 176, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 176, Accuracy: 0.5
# Checkpoint saved for epoch 176
# TRAINING: cnn[7], Epoch 177, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 177, Accuracy: 0.5
# Checkpoint saved for epoch 177
# TRAINING: cnn[7], Epoch 178, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 178, Accuracy: 0.5
# Checkpoint saved for epoch 178
# TRAINING: cnn[7], Epoch 179, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 179, Accuracy: 0.5
# Checkpoint saved for epoch 179
# TRAINING: cnn[7], Epoch 180, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 180, Accuracy: 0.5
# Checkpoint saved for epoch 180
# TRAINING: cnn[7], Epoch 181, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 181, Accuracy: 0.5
# Checkpoint saved for epoch 181
# TRAINING: cnn[7], Epoch 182, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 182, Accuracy: 0.5
# Checkpoint saved for epoch 182
# TRAINING: cnn[7], Epoch 183, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 183, Accuracy: 0.5
# Checkpoint saved for epoch 183
# TRAINING: cnn[7], Epoch 184, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 184, Accuracy: 0.5
# Checkpoint saved for epoch 184
# TRAINING: cnn[7], Epoch 185, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 185, Accuracy: 0.5
# Checkpoint saved for epoch 185
# TRAINING: cnn[7], Epoch 186, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 186, Accuracy: 0.5
# Checkpoint saved for epoch 186
# TRAINING: cnn[7], Epoch 187, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 187, Accuracy: 0.5
# Checkpoint saved for epoch 187
# TRAINING: cnn[7], Epoch 188, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 188, Accuracy: 0.5
# Checkpoint saved for epoch 188
# TRAINING: cnn[7], Epoch 189, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 189, Accuracy: 0.5
# Checkpoint saved for epoch 189
# TRAINING: cnn[7], Epoch 190, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 190, Accuracy: 0.5
# Checkpoint saved for epoch 190
# TRAINING: cnn[7], Epoch 191, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 191, Accuracy: 0.5
# Checkpoint saved for epoch 191
# TRAINING: cnn[7], Epoch 192, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 192, Accuracy: 0.5
# Checkpoint saved for epoch 192
# TRAINING: cnn[7], Epoch 193, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 193, Accuracy: 0.5
# Checkpoint saved for epoch 193
# TRAINING: cnn[7], Epoch 194, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 194, Accuracy: 0.5
# Checkpoint saved for epoch 194
# TRAINING: cnn[7], Epoch 195, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 195, Accuracy: 0.5
# Checkpoint saved for epoch 195
# TRAINING: cnn[7], Epoch 196, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 196, Accuracy: 0.5
# Checkpoint saved for epoch 196
# TRAINING: cnn[7], Epoch 197, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 197, Accuracy: 0.5
# Checkpoint saved for epoch 197
# TRAINING: cnn[7], Epoch 198, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 198, Accuracy: 0.5
# Checkpoint saved for epoch 198
# TRAINING: cnn[7], Epoch 199, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 199, Accuracy: 0.5
# Checkpoint saved for epoch 199
# TRAINING: cnn[7], Epoch 200, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 200, Accuracy: 0.5
# Checkpoint saved for epoch 200
# TRAINING: cnn[7], Epoch 201, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 201, Accuracy: 0.5
# Checkpoint saved for epoch 201
# TRAINING: cnn[7], Epoch 202, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 202, Accuracy: 0.5
# Checkpoint saved for epoch 202
# TRAINING: cnn[7], Epoch 203, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 203, Accuracy: 0.5
# Checkpoint saved for epoch 203
# TRAINING: cnn[7], Epoch 204, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 204, Accuracy: 0.5
# Checkpoint saved for epoch 204
# TRAINING: cnn[7], Epoch 205, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 205, Accuracy: 0.5
# Checkpoint saved for epoch 205
# TRAINING: cnn[7], Epoch 206, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 206, Accuracy: 0.5
# Checkpoint saved for epoch 206
# TRAINING: cnn[7], Epoch 207, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 207, Accuracy: 0.5
# Checkpoint saved for epoch 207
# TRAINING: cnn[7], Epoch 208, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 208, Accuracy: 0.5
# Checkpoint saved for epoch 208
# TRAINING: cnn[7], Epoch 209, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 209, Accuracy: 0.5
# Checkpoint saved for epoch 209
# TRAINING: cnn[7], Epoch 210, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 210, Accuracy: 0.5
# Checkpoint saved for epoch 210
# TRAINING: cnn[7], Epoch 211, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 211, Accuracy: 0.5
# Checkpoint saved for epoch 211
# TRAINING: cnn[7], Epoch 212, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 212, Accuracy: 0.5
# Checkpoint saved for epoch 212
# TRAINING: cnn[7], Epoch 213, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 213, Accuracy: 0.5
# Checkpoint saved for epoch 213
# TRAINING: cnn[7], Epoch 214, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 214, Accuracy: 0.5
# Checkpoint saved for epoch 214
# TRAINING: cnn[7], Epoch 215, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 215, Accuracy: 0.5
# Checkpoint saved for epoch 215
# TRAINING: cnn[7], Epoch 216, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 216, Accuracy: 0.5
# Checkpoint saved for epoch 216
# TRAINING: cnn[7], Epoch 217, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 217, Accuracy: 0.5
# Checkpoint saved for epoch 217
# TRAINING: cnn[7], Epoch 218, Loss: 0.6931470036506653
# TRAINING: cnn[7], Epoch 218, Accuracy: 0.5
# Checkpoint saved for epoch 218
# TRAINING: cnn[7], Epoch 219, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 219, Accuracy: 0.5
# Checkpoint saved for epoch 219
# TRAINING: cnn[7], Epoch 220, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 220, Accuracy: 0.5
# Checkpoint saved for epoch 220
# TRAINING: cnn[7], Epoch 221, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 221, Accuracy: 0.5
# Checkpoint saved for epoch 221
# TRAINING: cnn[7], Epoch 222, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 222, Accuracy: 0.5
# Checkpoint saved for epoch 222
# TRAINING: cnn[7], Epoch 223, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 223, Accuracy: 0.5
# Checkpoint saved for epoch 223
# TRAINING: cnn[7], Epoch 224, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 224, Accuracy: 0.5
# Checkpoint saved for epoch 224
# TRAINING: cnn[7], Epoch 225, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 225, Accuracy: 0.5
# Checkpoint saved for epoch 225
# TRAINING: cnn[7], Epoch 226, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 226, Accuracy: 0.5
# Checkpoint saved for epoch 226
# TRAINING: cnn[7], Epoch 227, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 227, Accuracy: 0.5
# Checkpoint saved for epoch 227
# TRAINING: cnn[7], Epoch 228, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 228, Accuracy: 0.5
# Checkpoint saved for epoch 228
# TRAINING: cnn[7], Epoch 229, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 229, Accuracy: 0.5
# Checkpoint saved for epoch 229
# TRAINING: cnn[7], Epoch 230, Loss: 0.6931472420692444
# TRAINING: cnn[7], Epoch 230, Accuracy: 0.5
# Checkpoint saved for epoch 230
# TRAINING: cnn[7], Epoch 231, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 231, Accuracy: 0.5
# Checkpoint saved for epoch 231
# TRAINING: cnn[7], Epoch 232, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 232, Accuracy: 0.5
# Checkpoint saved for epoch 232
# TRAINING: cnn[7], Epoch 233, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 233, Accuracy: 0.5
# Checkpoint saved for epoch 233
# TRAINING: cnn[7], Epoch 234, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 234, Accuracy: 0.5
# Checkpoint saved for epoch 234
# TRAINING: cnn[7], Epoch 235, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 235, Accuracy: 0.5
# Checkpoint saved for epoch 235
# TRAINING: cnn[7], Epoch 236, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 236, Accuracy: 0.5
# Checkpoint saved for epoch 236
# TRAINING: cnn[7], Epoch 237, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 237, Accuracy: 0.5
# Checkpoint saved for epoch 237
# TRAINING: cnn[7], Epoch 238, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 238, Accuracy: 0.5
# Checkpoint saved for epoch 238
# TRAINING: cnn[7], Epoch 239, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 239, Accuracy: 0.5
# Checkpoint saved for epoch 239
# TRAINING: cnn[7], Epoch 240, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 240, Accuracy: 0.5
# Checkpoint saved for epoch 240
# TRAINING: cnn[7], Epoch 241, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 241, Accuracy: 0.5
# Checkpoint saved for epoch 241
# TRAINING: cnn[7], Epoch 242, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 242, Accuracy: 0.5
# Checkpoint saved for epoch 242
# TRAINING: cnn[7], Epoch 243, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 243, Accuracy: 0.5
# Checkpoint saved for epoch 243
# TRAINING: cnn[7], Epoch 244, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 244, Accuracy: 0.5
# Checkpoint saved for epoch 244
# TRAINING: cnn[7], Epoch 245, Loss: 0.6931470036506653
# TRAINING: cnn[7], Epoch 245, Accuracy: 0.5
# Checkpoint saved for epoch 245
# TRAINING: cnn[7], Epoch 246, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 246, Accuracy: 0.5
# Checkpoint saved for epoch 246
# TRAINING: cnn[7], Epoch 247, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 247, Accuracy: 0.5
# Checkpoint saved for epoch 247
# TRAINING: cnn[7], Epoch 248, Loss: 0.6931470036506653
# TRAINING: cnn[7], Epoch 248, Accuracy: 0.5
# Checkpoint saved for epoch 248
# TRAINING: cnn[7], Epoch 249, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 249, Accuracy: 0.5
# Checkpoint saved for epoch 249
# TRAINING: cnn[7], Epoch 250, Loss: 0.6931470036506653
# TRAINING: cnn[7], Epoch 250, Accuracy: 0.5
# Checkpoint saved for epoch 250
# TRAINING: cnn[7], Epoch 251, Loss: 0.6931470036506653
# TRAINING: cnn[7], Epoch 251, Accuracy: 0.5
# Checkpoint saved for epoch 251
# TRAINING: cnn[7], Epoch 252, Loss: 0.6931469440460205
# TRAINING: cnn[7], Epoch 252, Accuracy: 0.5
# Checkpoint saved for epoch 252
# TRAINING: cnn[7], Epoch 253, Loss: 0.6931468844413757
# TRAINING: cnn[7], Epoch 253, Accuracy: 0.5
# Checkpoint saved for epoch 253
# TRAINING: cnn[7], Epoch 254, Loss: 0.6931469440460205
# TRAINING: cnn[7], Epoch 254, Accuracy: 0.5
# Checkpoint saved for epoch 254
# TRAINING: cnn[7], Epoch 255, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 255, Accuracy: 0.5
# Checkpoint saved for epoch 255
# TRAINING: cnn[7], Epoch 256, Loss: 0.6931468844413757
# TRAINING: cnn[7], Epoch 256, Accuracy: 0.5
# Checkpoint saved for epoch 256
# TRAINING: cnn[7], Epoch 257, Loss: 0.6931467652320862
# TRAINING: cnn[7], Epoch 257, Accuracy: 0.5
# Checkpoint saved for epoch 257
# TRAINING: cnn[7], Epoch 258, Loss: 0.6931469440460205
# TRAINING: cnn[7], Epoch 258, Accuracy: 0.5
# Checkpoint saved for epoch 258
# TRAINING: cnn[7], Epoch 259, Loss: 0.6931468844413757
# TRAINING: cnn[7], Epoch 259, Accuracy: 0.5
# Checkpoint saved for epoch 259
# TRAINING: cnn[7], Epoch 260, Loss: 0.6931468844413757
# TRAINING: cnn[7], Epoch 260, Accuracy: 0.5
# Checkpoint saved for epoch 260
# TRAINING: cnn[7], Epoch 261, Loss: 0.693146824836731
# TRAINING: cnn[7], Epoch 261, Accuracy: 0.5
# Checkpoint saved for epoch 261
# TRAINING: cnn[7], Epoch 262, Loss: 0.6931469440460205
# TRAINING: cnn[7], Epoch 262, Accuracy: 0.5
# Checkpoint saved for epoch 262
# TRAINING: cnn[7], Epoch 263, Loss: 0.6931467652320862
# TRAINING: cnn[7], Epoch 263, Accuracy: 0.5
# Checkpoint saved for epoch 263
# TRAINING: cnn[7], Epoch 264, Loss: 0.693146824836731
# TRAINING: cnn[7], Epoch 264, Accuracy: 0.5
# Checkpoint saved for epoch 264
# TRAINING: cnn[7], Epoch 265, Loss: 0.6931467652320862
# TRAINING: cnn[7], Epoch 265, Accuracy: 0.5
# Checkpoint saved for epoch 265
# TRAINING: cnn[7], Epoch 266, Loss: 0.6931467652320862
# TRAINING: cnn[7], Epoch 266, Accuracy: 0.5
# Checkpoint saved for epoch 266
# TRAINING: cnn[7], Epoch 267, Loss: 0.6931467056274414
# TRAINING: cnn[7], Epoch 267, Accuracy: 0.5
# Checkpoint saved for epoch 267
# TRAINING: cnn[7], Epoch 268, Loss: 0.6931466460227966
# TRAINING: cnn[7], Epoch 268, Accuracy: 0.5
# Checkpoint saved for epoch 268
# TRAINING: cnn[7], Epoch 269, Loss: 0.6931466460227966
# TRAINING: cnn[7], Epoch 269, Accuracy: 0.5
# Checkpoint saved for epoch 269
# TRAINING: cnn[7], Epoch 270, Loss: 0.6931465268135071
# TRAINING: cnn[7], Epoch 270, Accuracy: 0.5
# Checkpoint saved for epoch 270
# TRAINING: cnn[7], Epoch 271, Loss: 0.6931465268135071
# TRAINING: cnn[7], Epoch 271, Accuracy: 0.5
# Checkpoint saved for epoch 271
# TRAINING: cnn[7], Epoch 272, Loss: 0.6931463479995728
# TRAINING: cnn[7], Epoch 272, Accuracy: 0.5
# Checkpoint saved for epoch 272
# TRAINING: cnn[7], Epoch 273, Loss: 0.6931462287902832
# TRAINING: cnn[7], Epoch 273, Accuracy: 0.5
# Checkpoint saved for epoch 273
# TRAINING: cnn[7], Epoch 274, Loss: 0.6931461691856384
# TRAINING: cnn[7], Epoch 274, Accuracy: 0.5
# Checkpoint saved for epoch 274
# TRAINING: cnn[7], Epoch 275, Loss: 0.6931456327438354
# TRAINING: cnn[7], Epoch 275, Accuracy: 0.5
# Checkpoint saved for epoch 275
# TRAINING: cnn[7], Epoch 276, Loss: 0.6931454539299011
# TRAINING: cnn[7], Epoch 276, Accuracy: 0.5
# Checkpoint saved for epoch 276
# TRAINING: cnn[7], Epoch 277, Loss: 0.6931450963020325
# TRAINING: cnn[7], Epoch 277, Accuracy: 0.5
# Checkpoint saved for epoch 277
# TRAINING: cnn[7], Epoch 278, Loss: 0.6931447386741638
# TRAINING: cnn[7], Epoch 278, Accuracy: 0.5
# Checkpoint saved for epoch 278
# TRAINING: cnn[7], Epoch 279, Loss: 0.6931440830230713
# TRAINING: cnn[7], Epoch 279, Accuracy: 0.5
# Checkpoint saved for epoch 279
# TRAINING: cnn[7], Epoch 280, Loss: 0.6931435465812683
# TRAINING: cnn[7], Epoch 280, Accuracy: 0.5
# Checkpoint saved for epoch 280
# TRAINING: cnn[7], Epoch 281, Loss: 0.6931436657905579
# TRAINING: cnn[7], Epoch 281, Accuracy: 0.5
# Checkpoint saved for epoch 281
# TRAINING: cnn[7], Epoch 282, Loss: 0.6931458711624146
# TRAINING: cnn[7], Epoch 282, Accuracy: 0.5
# Checkpoint saved for epoch 282
# TRAINING: cnn[7], Epoch 283, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 283, Accuracy: 0.5
# Checkpoint saved for epoch 283
# TRAINING: cnn[7], Epoch 284, Loss: 0.6931476593017578
# TRAINING: cnn[7], Epoch 284, Accuracy: 0.5
# Checkpoint saved for epoch 284
# TRAINING: cnn[7], Epoch 285, Loss: 0.6931473612785339
# TRAINING: cnn[7], Epoch 285, Accuracy: 0.5
# Checkpoint saved for epoch 285
# TRAINING: cnn[7], Epoch 286, Loss: 0.6931465864181519
# TRAINING: cnn[7], Epoch 286, Accuracy: 0.5
# Checkpoint saved for epoch 286
# TRAINING: cnn[7], Epoch 287, Loss: 0.6931461095809937
# TRAINING: cnn[7], Epoch 287, Accuracy: 0.5
# Checkpoint saved for epoch 287
# TRAINING: cnn[7], Epoch 288, Loss: 0.6931462287902832
# TRAINING: cnn[7], Epoch 288, Accuracy: 0.5
# Checkpoint saved for epoch 288
# TRAINING: cnn[7], Epoch 289, Loss: 0.6931467056274414
# TRAINING: cnn[7], Epoch 289, Accuracy: 0.5
# Checkpoint saved for epoch 289
# TRAINING: cnn[7], Epoch 290, Loss: 0.6931464672088623
# TRAINING: cnn[7], Epoch 290, Accuracy: 0.5
# Checkpoint saved for epoch 290
# TRAINING: cnn[7], Epoch 291, Loss: 0.6931458115577698
# TRAINING: cnn[7], Epoch 291, Accuracy: 0.5
# Checkpoint saved for epoch 291
# TRAINING: cnn[7], Epoch 292, Loss: 0.6931456327438354
# TRAINING: cnn[7], Epoch 292, Accuracy: 0.5
# Checkpoint saved for epoch 292
# TRAINING: cnn[7], Epoch 293, Loss: 0.6931458115577698
# TRAINING: cnn[7], Epoch 293, Accuracy: 0.5
# Checkpoint saved for epoch 293
# TRAINING: cnn[7], Epoch 294, Loss: 0.693145751953125
# TRAINING: cnn[7], Epoch 294, Accuracy: 0.5
# Checkpoint saved for epoch 294
# TRAINING: cnn[7], Epoch 295, Loss: 0.6931452751159668
# TRAINING: cnn[7], Epoch 295, Accuracy: 0.5
# Checkpoint saved for epoch 295
# TRAINING: cnn[7], Epoch 296, Loss: 0.6931450963020325
# TRAINING: cnn[7], Epoch 296, Accuracy: 0.5
# Checkpoint saved for epoch 296
# TRAINING: cnn[7], Epoch 297, Loss: 0.6931449174880981
# TRAINING: cnn[7], Epoch 297, Accuracy: 0.5
# Checkpoint saved for epoch 297
# TRAINING: cnn[7], Epoch 298, Loss: 0.6931447386741638
# TRAINING: cnn[7], Epoch 298, Accuracy: 0.5
# Checkpoint saved for epoch 298
# TRAINING: cnn[7], Epoch 299, Loss: 0.6931445002555847
# TRAINING: cnn[7], Epoch 299, Accuracy: 0.5
# Checkpoint saved for epoch 299
# TRAINING: cnn[7], Epoch 300, Loss: 0.6931442022323608
# TRAINING: cnn[7], Epoch 300, Accuracy: 0.5
# Checkpoint saved for epoch 300
# TRAINING: cnn[7], Epoch 301, Loss: 0.6931440830230713
# TRAINING: cnn[7], Epoch 301, Accuracy: 0.5
# Checkpoint saved for epoch 301
# TRAINING: cnn[7], Epoch 302, Loss: 0.6931436657905579
# TRAINING: cnn[7], Epoch 302, Accuracy: 0.5
# Checkpoint saved for epoch 302
# TRAINING: cnn[7], Epoch 303, Loss: 0.6931431889533997
# TRAINING: cnn[7], Epoch 303, Accuracy: 0.5
# Checkpoint saved for epoch 303
# TRAINING: cnn[7], Epoch 304, Loss: 0.6931425929069519
# TRAINING: cnn[7], Epoch 304, Accuracy: 0.5
# Checkpoint saved for epoch 304
# TRAINING: cnn[7], Epoch 305, Loss: 0.6931424140930176
# TRAINING: cnn[7], Epoch 305, Accuracy: 0.5
# Checkpoint saved for epoch 305
# TRAINING: cnn[7], Epoch 306, Loss: 0.6931421160697937
# TRAINING: cnn[7], Epoch 306, Accuracy: 0.5
# Checkpoint saved for epoch 306
# TRAINING: cnn[7], Epoch 307, Loss: 0.6931410431861877
# TRAINING: cnn[7], Epoch 307, Accuracy: 0.5
# Checkpoint saved for epoch 307
# TRAINING: cnn[7], Epoch 308, Loss: 0.6931406259536743
# TRAINING: cnn[7], Epoch 308, Accuracy: 0.5
# Checkpoint saved for epoch 308
# TRAINING: cnn[7], Epoch 309, Loss: 0.6931400895118713
# TRAINING: cnn[7], Epoch 309, Accuracy: 0.5
# Checkpoint saved for epoch 309
# TRAINING: cnn[7], Epoch 310, Loss: 0.6931391954421997
# TRAINING: cnn[7], Epoch 310, Accuracy: 0.5
# Checkpoint saved for epoch 310
# TRAINING: cnn[7], Epoch 311, Loss: 0.6931371688842773
# TRAINING: cnn[7], Epoch 311, Accuracy: 0.5
# Checkpoint saved for epoch 311
# TRAINING: cnn[7], Epoch 312, Loss: 0.6931350231170654
# TRAINING: cnn[7], Epoch 312, Accuracy: 0.5
# Checkpoint saved for epoch 312
# TRAINING: cnn[7], Epoch 313, Loss: 0.6931340098381042
# TRAINING: cnn[7], Epoch 313, Accuracy: 0.5
# Checkpoint saved for epoch 313
# TRAINING: cnn[7], Epoch 314, Loss: 0.6931294798851013
# TRAINING: cnn[7], Epoch 314, Accuracy: 0.5
# Checkpoint saved for epoch 314
# TRAINING: cnn[7], Epoch 315, Loss: 0.6931239366531372
# TRAINING: cnn[7], Epoch 315, Accuracy: 0.66796875
# Checkpoint saved for epoch 315
# TRAINING: cnn[7], Epoch 316, Loss: 0.6931189894676208
# TRAINING: cnn[7], Epoch 316, Accuracy: 0.5
# Checkpoint saved for epoch 316
# TRAINING: cnn[7], Epoch 317, Loss: 0.6931102275848389
# TRAINING: cnn[7], Epoch 317, Accuracy: 0.5
# Checkpoint saved for epoch 317
# TRAINING: cnn[7], Epoch 318, Loss: 0.6931082010269165
# TRAINING: cnn[7], Epoch 318, Accuracy: 0.5
# Checkpoint saved for epoch 318
# TRAINING: cnn[7], Epoch 319, Loss: 0.6931037902832031
# TRAINING: cnn[7], Epoch 319, Accuracy: 0.5
# Checkpoint saved for epoch 319
# TRAINING: cnn[7], Epoch 320, Loss: 0.693088710308075
# TRAINING: cnn[7], Epoch 320, Accuracy: 0.5
# Checkpoint saved for epoch 320
# TRAINING: cnn[7], Epoch 321, Loss: 0.6931383609771729
# TRAINING: cnn[7], Epoch 321, Accuracy: 0.5
# Checkpoint saved for epoch 321
# TRAINING: cnn[7], Epoch 322, Loss: 0.6931390166282654
# TRAINING: cnn[7], Epoch 322, Accuracy: 0.5
# Checkpoint saved for epoch 322
# TRAINING: cnn[7], Epoch 323, Loss: 0.6931344270706177
# TRAINING: cnn[7], Epoch 323, Accuracy: 0.5
# Checkpoint saved for epoch 323
# TRAINING: cnn[7], Epoch 324, Loss: 0.6931397318840027
# TRAINING: cnn[7], Epoch 324, Accuracy: 0.5
# Checkpoint saved for epoch 324
# TRAINING: cnn[7], Epoch 325, Loss: 0.6931387186050415
# TRAINING: cnn[7], Epoch 325, Accuracy: 0.5
# Checkpoint saved for epoch 325
# TRAINING: cnn[7], Epoch 326, Loss: 0.693143367767334
# TRAINING: cnn[7], Epoch 326, Accuracy: 0.5
# Checkpoint saved for epoch 326
# TRAINING: cnn[7], Epoch 327, Loss: 0.6931445598602295
# TRAINING: cnn[7], Epoch 327, Accuracy: 0.5
# Checkpoint saved for epoch 327
# TRAINING: cnn[7], Epoch 328, Loss: 0.6931440830230713
# TRAINING: cnn[7], Epoch 328, Accuracy: 0.5
# Checkpoint saved for epoch 328
# TRAINING: cnn[7], Epoch 329, Loss: 0.6931471824645996
# TRAINING: cnn[7], Epoch 329, Accuracy: 0.5
# Checkpoint saved for epoch 329
# TRAINING: cnn[7], Epoch 330, Loss: 0.6931473016738892
# TRAINING: cnn[7], Epoch 330, Accuracy: 0.5
# Checkpoint saved for epoch 330
# TRAINING: cnn[7], Epoch 331, Loss: 0.6931469440460205
# TRAINING: cnn[7], Epoch 331, Accuracy: 0.5
# Checkpoint saved for epoch 331
# TRAINING: cnn[7], Epoch 332, Loss: 0.6931467056274414
# TRAINING: cnn[7], Epoch 332, Accuracy: 0.5
# Checkpoint saved for epoch 332
# TRAINING: cnn[7], Epoch 333, Loss: 0.693146824836731
# TRAINING: cnn[7], Epoch 333, Accuracy: 0.5
# Checkpoint saved for epoch 333
# TRAINING: cnn[7], Epoch 334, Loss: 0.6931470632553101
# TRAINING: cnn[7], Epoch 334, Accuracy: 0.5
# Checkpoint saved for epoch 334
# TRAINING: cnn[7], Epoch 335, Loss: 0.6931467056274414
# TRAINING: cnn[7], Epoch 335, Accuracy: 0.5
# Checkpoint saved for epoch 335
# TRAINING: cnn[7], Epoch 336, Loss: 0.6931467056274414
# TRAINING: cnn[7], Epoch 336, Accuracy: 0.5
# Checkpoint saved for epoch 336
# TRAINING: cnn[7], Epoch 337, Loss: 0.6931467056274414
# TRAINING: cnn[7], Epoch 337, Accuracy: 0.5
# Checkpoint saved for epoch 337
# TRAINING: cnn[7], Epoch 338, Loss: 0.6931463479995728
# TRAINING: cnn[7], Epoch 338, Accuracy: 0.5
# Checkpoint saved for epoch 338
# TRAINING: cnn[7], Epoch 339, Loss: 0.6931461691856384
# TRAINING: cnn[7], Epoch 339, Accuracy: 0.5
# Checkpoint saved for epoch 339
# TRAINING: cnn[7], Epoch 340, Loss: 0.6931458711624146
# TRAINING: cnn[7], Epoch 340, Accuracy: 0.5
# Checkpoint saved for epoch 340
# TRAINING: cnn[7], Epoch 341, Loss: 0.6931455135345459
# TRAINING: cnn[7], Epoch 341, Accuracy: 0.5
# Checkpoint saved for epoch 341
# TRAINING: cnn[7], Epoch 342, Loss: 0.6931449770927429
# TRAINING: cnn[7], Epoch 342, Accuracy: 0.5
# Checkpoint saved for epoch 342
# TRAINING: cnn[7], Epoch 343, Loss: 0.6931444406509399
# TRAINING: cnn[7], Epoch 343, Accuracy: 0.5
# Checkpoint saved for epoch 343
# TRAINING: cnn[7], Epoch 344, Loss: 0.6931438446044922
# TRAINING: cnn[7], Epoch 344, Accuracy: 0.5
# Checkpoint saved for epoch 344
# TRAINING: cnn[7], Epoch 345, Loss: 0.6931430697441101
# TRAINING: cnn[7], Epoch 345, Accuracy: 0.5
# Checkpoint saved for epoch 345
# TRAINING: cnn[7], Epoch 346, Loss: 0.6931423544883728
# TRAINING: cnn[7], Epoch 346, Accuracy: 0.5
# Checkpoint saved for epoch 346
# TRAINING: cnn[7], Epoch 347, Loss: 0.6931410431861877
# TRAINING: cnn[7], Epoch 347, Accuracy: 0.5
# Checkpoint saved for epoch 347
# TRAINING: cnn[7], Epoch 348, Loss: 0.6931403875350952
# TRAINING: cnn[7], Epoch 348, Accuracy: 0.5
# Checkpoint saved for epoch 348
# TRAINING: cnn[7], Epoch 349, Loss: 0.6931386590003967
# TRAINING: cnn[7], Epoch 349, Accuracy: 0.5
# Checkpoint saved for epoch 349
# TRAINING: cnn[7], Epoch 350, Loss: 0.6931359767913818
# TRAINING: cnn[7], Epoch 350, Accuracy: 0.5
# Checkpoint saved for epoch 350
# TRAINING: cnn[7], Epoch 351, Loss: 0.6931471228599548
# TRAINING: cnn[7], Epoch 351, Accuracy: 0.5
# Checkpoint saved for epoch 351
# TRAINING: cnn[7], Epoch 352, Loss: 0.6931648850440979
# TRAINING: cnn[7], Epoch 352, Accuracy: 0.5
# Checkpoint saved for epoch 352
# TRAINING: cnn[7], Epoch 353, Loss: 0.6931555271148682
# TRAINING: cnn[7], Epoch 353, Accuracy: 0.5
# Checkpoint saved for epoch 353
# TRAINING: cnn[7], Epoch 354, Loss: 0.6931407451629639
# TRAINING: cnn[7], Epoch 354, Accuracy: 0.5
# Checkpoint saved for epoch 354
# TRAINING: cnn[7], Epoch 355, Loss: 0.6931453347206116
# TRAINING: cnn[7], Epoch 355, Accuracy: 0.5
# Checkpoint saved for epoch 355
# TRAINING: cnn[7], Epoch 356, Loss: 0.6931536197662354
# TRAINING: cnn[7], Epoch 356, Accuracy: 0.5
# Checkpoint saved for epoch 356
# TRAINING: cnn[7], Epoch 357, Loss: 0.6931175589561462
# TRAINING: cnn[7], Epoch 357, Accuracy: 0.5
# Checkpoint saved for epoch 357
# TRAINING: cnn[7], Epoch 358, Loss: 0.6931635141372681
# TRAINING: cnn[7], Epoch 358, Accuracy: 0.5
# Checkpoint saved for epoch 358
# TRAINING: cnn[7], Epoch 359, Loss: 0.6931575536727905
# TRAINING: cnn[7], Epoch 359, Accuracy: 0.5
# Checkpoint saved for epoch 359
# TRAINING: cnn[7], Epoch 360, Loss: 0.6931908130645752
# TRAINING: cnn[7], Epoch 360, Accuracy: 0.5
# Checkpoint saved for epoch 360
# TRAINING: cnn[7], Epoch 361, Loss: 0.6931697726249695
# TRAINING: cnn[7], Epoch 361, Accuracy: 0.5
# Checkpoint saved for epoch 361
# TRAINING: cnn[7], Epoch 362, Loss: 0.6931380033493042
# TRAINING: cnn[7], Epoch 362, Accuracy: 0.5
# Checkpoint saved for epoch 362
# TRAINING: cnn[7], Epoch 363, Loss: 0.6931390762329102
# TRAINING: cnn[7], Epoch 363, Accuracy: 0.5
# Checkpoint saved for epoch 363
# TRAINING: cnn[7], Epoch 364, Loss: 0.6931540369987488
# TRAINING: cnn[7], Epoch 364, Accuracy: 0.5
# Checkpoint saved for epoch 364
# TRAINING: cnn[7], Epoch 365, Loss: 0.6931555867195129
# TRAINING: cnn[7], Epoch 365, Accuracy: 0.5
# Checkpoint saved for epoch 365
# TRAINING: cnn[7], Epoch 366, Loss: 0.6931424736976624
# TRAINING: cnn[7], Epoch 366, Accuracy: 0.5
# Checkpoint saved for epoch 366
# TRAINING: cnn[7], Epoch 367, Loss: 0.6931264400482178
# TRAINING: cnn[7], Epoch 367, Accuracy: 0.5
# Checkpoint saved for epoch 367
# TRAINING: cnn[7], Epoch 368, Loss: 0.6931350827217102
# TRAINING: cnn[7], Epoch 368, Accuracy: 0.5
# Checkpoint saved for epoch 368
# TRAINING: cnn[7], Epoch 369, Loss: 0.6931455135345459
# TRAINING: cnn[7], Epoch 369, Accuracy: 0.5
# Checkpoint saved for epoch 369
# TRAINING: cnn[7], Epoch 370, Loss: 0.6931464672088623
# TRAINING: cnn[7], Epoch 370, Accuracy: 0.5
# Checkpoint saved for epoch 370
# TRAINING: cnn[7], Epoch 371, Loss: 0.6931379437446594
# TRAINING: cnn[7], Epoch 371, Accuracy: 0.5
# Checkpoint saved for epoch 371
# TRAINING: cnn[7], Epoch 372, Loss: 0.6931309700012207
# TRAINING: cnn[7], Epoch 372, Accuracy: 0.5
# Checkpoint saved for epoch 372
# TRAINING: cnn[7], Epoch 373, Loss: 0.6931394338607788
# TRAINING: cnn[7], Epoch 373, Accuracy: 0.5
# Checkpoint saved for epoch 373
# TRAINING: cnn[7], Epoch 374, Loss: 0.693142294883728
# TRAINING: cnn[7], Epoch 374, Accuracy: 0.5
# Checkpoint saved for epoch 374
# TRAINING: cnn[7], Epoch 375, Loss: 0.693142294883728
# TRAINING: cnn[7], Epoch 375, Accuracy: 0.5
# Checkpoint saved for epoch 375
# ...
# Checkpoint saved for epoch 799
# TRAINING: cnn[6], Epoch 800, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 800, Accuracy: 0.5
# Checkpoint saved for epoch 800
# TRAINING: cnn[6], Epoch 801, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 801, Accuracy: 0.5
# Checkpoint saved for epoch 801
# TRAINING: cnn[6], Epoch 802, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 802, Accuracy: 0.5
# Checkpoint saved for epoch 802
# TRAINING: cnn[6], Epoch 803, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 803, Accuracy: 0.5
# Checkpoint saved for epoch 803
# TRAINING: cnn[6], Epoch 804, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 804, Accuracy: 0.5
# Checkpoint saved for epoch 804
# TRAINING: cnn[6], Epoch 805, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 805, Accuracy: 0.5
# Checkpoint saved for epoch 805
# TRAINING: cnn[6], Epoch 806, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 806, Accuracy: 0.5
# Checkpoint saved for epoch 806
# TRAINING: cnn[6], Epoch 807, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 807, Accuracy: 0.5
# Checkpoint saved for epoch 807
# TRAINING: cnn[6], Epoch 808, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 808, Accuracy: 0.5
# Checkpoint saved for epoch 808
# TRAINING: cnn[6], Epoch 809, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 809, Accuracy: 0.5
# Checkpoint saved for epoch 809
# TRAINING: cnn[6], Epoch 810, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 810, Accuracy: 0.5
# Checkpoint saved for epoch 810
# TRAINING: cnn[6], Epoch 811, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 811, Accuracy: 0.5
# Checkpoint saved for epoch 811
# TRAINING: cnn[6], Epoch 812, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 812, Accuracy: 0.5
# Checkpoint saved for epoch 812
# TRAINING: cnn[6], Epoch 813, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 813, Accuracy: 0.5
# Checkpoint saved for epoch 813
# TRAINING: cnn[6], Epoch 814, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 814, Accuracy: 0.5
# Checkpoint saved for epoch 814
# TRAINING: cnn[6], Epoch 815, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 815, Accuracy: 0.5
# Checkpoint saved for epoch 815
# TRAINING: cnn[6], Epoch 816, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 816, Accuracy: 0.5
# Checkpoint saved for epoch 816
# TRAINING: cnn[6], Epoch 817, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 817, Accuracy: 0.5
# Checkpoint saved for epoch 817
# TRAINING: cnn[6], Epoch 818, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 818, Accuracy: 0.5
# Checkpoint saved for epoch 818
# TRAINING: cnn[6], Epoch 819, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 819, Accuracy: 0.5
# Checkpoint saved for epoch 819
# TRAINING: cnn[6], Epoch 820, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 820, Accuracy: 0.5
# Checkpoint saved for epoch 820
# TRAINING: cnn[6], Epoch 821, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 821, Accuracy: 0.5
# Checkpoint saved for epoch 821
# TRAINING: cnn[6], Epoch 822, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 822, Accuracy: 0.5
# Checkpoint saved for epoch 822
# TRAINING: cnn[6], Epoch 823, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 823, Accuracy: 0.5
# Checkpoint saved for epoch 823
# TRAINING: cnn[6], Epoch 824, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 824, Accuracy: 0.5
# Checkpoint saved for epoch 824
# TRAINING: cnn[6], Epoch 825, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 825, Accuracy: 0.5
# Checkpoint saved for epoch 825
# TRAINING: cnn[6], Epoch 826, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 826, Accuracy: 0.5
# Checkpoint saved for epoch 826
# TRAINING: cnn[6], Epoch 827, Loss: 0.6931470036506653
# TRAINING: cnn[6], Epoch 827, Accuracy: 0.5
# Checkpoint saved for epoch 827
# TRAINING: cnn[6], Epoch 828, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 828, Accuracy: 0.5
# Checkpoint saved for epoch 828
# TRAINING: cnn[6], Epoch 829, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 829, Accuracy: 0.5
# Checkpoint saved for epoch 829
# TRAINING: cnn[6], Epoch 830, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 830, Accuracy: 0.5
# Checkpoint saved for epoch 830
# TRAINING: cnn[6], Epoch 831, Loss: 0.6931470632553101
# TRAINING: cnn[6], Epoch 831, Accuracy: 0.5
# Checkpoint saved for epoch 831
# TRAINING: cnn[6], Epoch 832, Loss: 0.6931470632553101
# TRAINING: cnn[6], Epoch 832, Accuracy: 0.5
# Checkpoint saved for epoch 832
# TRAINING: cnn[6], Epoch 833, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 833, Accuracy: 0.5
# Checkpoint saved for epoch 833
# TRAINING: cnn[6], Epoch 834, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 834, Accuracy: 0.5
# Checkpoint saved for epoch 834
# TRAINING: cnn[6], Epoch 835, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 835, Accuracy: 0.5
# Checkpoint saved for epoch 835
# TRAINING: cnn[6], Epoch 836, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 836, Accuracy: 0.5
# Checkpoint saved for epoch 836
# TRAINING: cnn[6], Epoch 837, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 837, Accuracy: 0.5
# Checkpoint saved for epoch 837
# TRAINING: cnn[6], Epoch 838, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 838, Accuracy: 0.5
# Checkpoint saved for epoch 838
# TRAINING: cnn[6], Epoch 839, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 839, Accuracy: 0.5
# Checkpoint saved for epoch 839
# TRAINING: cnn[6], Epoch 840, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 840, Accuracy: 0.5
# Checkpoint saved for epoch 840
# TRAINING: cnn[6], Epoch 841, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 841, Accuracy: 0.5
# Checkpoint saved for epoch 841
# TRAINING: cnn[6], Epoch 842, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 842, Accuracy: 0.5
# Checkpoint saved for epoch 842
# TRAINING: cnn[6], Epoch 843, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 843, Accuracy: 0.5
# Checkpoint saved for epoch 843
# TRAINING: cnn[6], Epoch 844, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 844, Accuracy: 0.5
# Checkpoint saved for epoch 844
# TRAINING: cnn[6], Epoch 845, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 845, Accuracy: 0.5
# Checkpoint saved for epoch 845
# TRAINING: cnn[6], Epoch 846, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 846, Accuracy: 0.5
# Checkpoint saved for epoch 846
# TRAINING: cnn[6], Epoch 847, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 847, Accuracy: 0.5
# Checkpoint saved for epoch 847
# TRAINING: cnn[6], Epoch 848, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 848, Accuracy: 0.5
# Checkpoint saved for epoch 848
# TRAINING: cnn[6], Epoch 849, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 849, Accuracy: 0.5
# Checkpoint saved for epoch 849
# TRAINING: cnn[6], Epoch 850, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 850, Accuracy: 0.5
# Checkpoint saved for epoch 850
# TRAINING: cnn[6], Epoch 851, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 851, Accuracy: 0.5
# Checkpoint saved for epoch 851
# TRAINING: cnn[6], Epoch 852, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 852, Accuracy: 0.5
# Checkpoint saved for epoch 852
# TRAINING: cnn[6], Epoch 853, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 853, Accuracy: 0.5
# Checkpoint saved for epoch 853
# TRAINING: cnn[6], Epoch 854, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 854, Accuracy: 0.5
# Checkpoint saved for epoch 854
# TRAINING: cnn[6], Epoch 855, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 855, Accuracy: 0.5
# Checkpoint saved for epoch 855
# TRAINING: cnn[6], Epoch 856, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 856, Accuracy: 0.5
# Checkpoint saved for epoch 856
# TRAINING: cnn[6], Epoch 857, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 857, Accuracy: 0.5
# Checkpoint saved for epoch 857
# TRAINING: cnn[6], Epoch 858, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 858, Accuracy: 0.5
# Checkpoint saved for epoch 858
# TRAINING: cnn[6], Epoch 859, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 859, Accuracy: 0.5
# Checkpoint saved for epoch 859
# TRAINING: cnn[6], Epoch 860, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 860, Accuracy: 0.5
# Checkpoint saved for epoch 860
# TRAINING: cnn[6], Epoch 861, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 861, Accuracy: 0.5
# Checkpoint saved for epoch 861
# TRAINING: cnn[6], Epoch 862, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 862, Accuracy: 0.5
# Checkpoint saved for epoch 862
# TRAINING: cnn[6], Epoch 863, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 863, Accuracy: 0.5
# Checkpoint saved for epoch 863
# TRAINING: cnn[6], Epoch 864, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 864, Accuracy: 0.5
# Checkpoint saved for epoch 864
# TRAINING: cnn[6], Epoch 865, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 865, Accuracy: 0.5
# Checkpoint saved for epoch 865
# TRAINING: cnn[6], Epoch 866, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 866, Accuracy: 0.5
# Checkpoint saved for epoch 866
# TRAINING: cnn[6], Epoch 867, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 867, Accuracy: 0.5
# Checkpoint saved for epoch 867
# TRAINING: cnn[6], Epoch 868, Loss: 0.6931470632553101
# TRAINING: cnn[6], Epoch 868, Accuracy: 0.5
# Checkpoint saved for epoch 868
# TRAINING: cnn[6], Epoch 869, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 869, Accuracy: 0.5
# Checkpoint saved for epoch 869
# TRAINING: cnn[6], Epoch 870, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 870, Accuracy: 0.5
# Checkpoint saved for epoch 870
# TRAINING: cnn[6], Epoch 871, Loss: 0.6931470632553101
# TRAINING: cnn[6], Epoch 871, Accuracy: 0.5
# Checkpoint saved for epoch 871
# TRAINING: cnn[6], Epoch 872, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 872, Accuracy: 0.5
# Checkpoint saved for epoch 872
# TRAINING: cnn[6], Epoch 873, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 873, Accuracy: 0.5
# Checkpoint saved for epoch 873
# TRAINING: cnn[6], Epoch 874, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 874, Accuracy: 0.5
# Checkpoint saved for epoch 874
# TRAINING: cnn[6], Epoch 875, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 875, Accuracy: 0.5
# Checkpoint saved for epoch 875
# TRAINING: cnn[6], Epoch 876, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 876, Accuracy: 0.5
# Checkpoint saved for epoch 876
# TRAINING: cnn[6], Epoch 877, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 877, Accuracy: 0.5
# Checkpoint saved for epoch 877
# TRAINING: cnn[6], Epoch 878, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 878, Accuracy: 0.5
# Checkpoint saved for epoch 878
# TRAINING: cnn[6], Epoch 879, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 879, Accuracy: 0.5
# Checkpoint saved for epoch 879
# TRAINING: cnn[6], Epoch 880, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 880, Accuracy: 0.5
# Checkpoint saved for epoch 880
# TRAINING: cnn[6], Epoch 881, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 881, Accuracy: 0.5
# Checkpoint saved for epoch 881
# TRAINING: cnn[6], Epoch 882, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 882, Accuracy: 0.5
# Checkpoint saved for epoch 882
# TRAINING: cnn[6], Epoch 883, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 883, Accuracy: 0.5
# Checkpoint saved for epoch 883
# TRAINING: cnn[6], Epoch 884, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 884, Accuracy: 0.5
# Checkpoint saved for epoch 884
# TRAINING: cnn[6], Epoch 885, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 885, Accuracy: 0.5
# Checkpoint saved for epoch 885
# TRAINING: cnn[6], Epoch 886, Loss: 0.6931472420692444
# TRAINING: cnn[6], Epoch 886, Accuracy: 0.5
# Checkpoint saved for epoch 886
# TRAINING: cnn[6], Epoch 887, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 887, Accuracy: 0.5
# Checkpoint saved for epoch 887
# TRAINING: cnn[6], Epoch 888, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 888, Accuracy: 0.5
# Checkpoint saved for epoch 888
# TRAINING: cnn[6], Epoch 889, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 889, Accuracy: 0.5
# Checkpoint saved for epoch 889
# TRAINING: cnn[6], Epoch 890, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 890, Accuracy: 0.5
# Checkpoint saved for epoch 890
# TRAINING: cnn[6], Epoch 891, Loss: 0.6931470632553101
# TRAINING: cnn[6], Epoch 891, Accuracy: 0.5
# Checkpoint saved for epoch 891
# TRAINING: cnn[6], Epoch 892, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 892, Accuracy: 0.5
# Checkpoint saved for epoch 892
# TRAINING: cnn[6], Epoch 893, Loss: 0.6931473016738892
# TRAINING: cnn[6], Epoch 893, Accuracy: 0.5
# Checkpoint saved for epoch 893
# TRAINING: cnn[6], Epoch 894, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 894, Accuracy: 0.5
# Checkpoint saved for epoch 894
# TRAINING: cnn[6], Epoch 895, Loss: 0.6931471228599548
# TRAINING: cnn[6], Epoch 895, Accuracy: 0.5
# Checkpoint saved for epoch 895
# TRAINING: cnn[6], Epoch 896, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 896, Accuracy: 0.5
# Checkpoint saved for epoch 896
# TRAINING: cnn[6], Epoch 897, Loss: 0.6931471824645996
# TRAINING: cnn[6], Epoch 897, Accuracy: 0.5
# Checkpoint saved for epoch 897
# TRAINING: cnn[6], Epoch 898, Loss: 0.6931470632553101
# TRAINING: cnn[6], Epoch 898, Accuracy: 0.5
# Checkpoint saved for epoch 898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 81
#      78 # Add dimensions for channels and width
#      79 # inputs = inputs.unsqueeze(1).unsqueeze(-1)
#      80 optimizer.zero_grad()
# ---> 81 output = cnn(inputs)
#      82 # Check for NaN in outputs
#      83 if torch.isnan(output).any():
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[16], line 41, in psa_CNN.forward(self, x)
#      39 x = torch.relu(self.conv1(x))
#      40 x = self.pool1(x)
# ---> 41 x = torch.relu(self.conv2(x))
#      42 x = self.pool2(x)
#      43 '''
#      44 x = torch.relu(self.conv3(x))
#      45 x = self.pool3(x)
#      46 x = torch.relu(self.conv4(x))
#      47 x = self.pool4(x)
#      48 '''
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:308, in Conv1d.forward(self, input)
#     307 def forward(self, input: Tensor) -> Tensor:
# --> 308     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:304, in Conv1d._conv_forward(self, input, weight, bias)
#     300 if self.padding_mode != 'zeros':
#     301     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     302                     weight, bias, self.stride,
#     303                     _single(0), self.dilation, self.groups)
# --> 304 return F.conv1d(input, weight, bias, self.stride,
#     305                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing the CNNs
#
# Using the resulting CNNs saved in the .pth files, we test each CNNs using the provided power traces.
#
# Currently the testing data is a subset of the training data. In the future, if we can generate more data, we will be able to use separate datasets.

# %%
# Run evaluation using testing data
# CURRENTLY USING TRAINING DATA TO TEST DATA: use separate dataset in the future
for i in range(7,-1,-1):
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=True)
        cnn.load_state_dict(checkpoint['cnn_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch']
        print(f"Checkpoint loaded. Resuming from epoch {start_epoch}")
        reached_target_acc = checkpoint['reached_acc']
        print(f"Previous reached accuracy: {reached_target_acc}")
        if reached_target_acc != 1:
            print(f"cnn_{i}\" did not reach accuracy of 1, skipping evaluation.\n\n")
            continue
    except FileNotFoundError:
        print(f"No checkpoint found for \"cnn_{i}\". Starting from scratch.")

    cnns[i].eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloaders[i]:
            inputs, labels = inputs.to(device), labels.to(device)
            # Add dimensions for channels and width
            inputs = inputs.unsqueeze(1).unsqueeze(-1)
            outputs = cnns[i](inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f"Accuracy: {100 * correct / total:.2f}%")
